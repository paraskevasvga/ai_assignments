# %% [markdown]
# # Lab 7: Inserting Word Embeddings with a Genetic Algorithm
#
# Welcome to the lab! Our goal is to insert new words (e.g., from the CIFAR-100 dataset) into a pre-trained Skip-Gram model *without* having to retrain the entire model from scratch.
#
# This is a common problem: how do you update a massive, trained model with new vocabulary?
#
# ---
#
# ### 🎯 Our Goal & Method
#
# We will implement a **(1+$\lambda$) Evolution Strategy (ES)**, a simple Genetic Algorithm. This algorithm will "evolve" a new vector for each missing word.
#
# The evolution will be guided by a custom **fitness function** that scores how "good" a candidate vector is. A good vector should:
#
# 1.  **Fit the Corpus:** The vector should have a high dot product with its *context* words (words it appears near) and a low dot product with *negative samples* (random words). This is the core idea of Skip-Gram.
# 2.  **Match the Space:** The vector's **norm** (length) should be similar to the average norm of existing words. This helps it "fit in" to the pre-existing geometric structure.
# 3.  **Match Semantics:** The vector should be close to known "anchor" words (e.g., we can manually specify that 'beaver' should be near 'animal').
#
# ### 👩‍💻 Your Task
#
# You will implement the core functions in `lab6.py`. This notebook will then use your functions to:
# * Load the pre-trained model and data.
# * Analyze the vocabulary overlap to find missing words.
# * Extract contexts for the missing words.
# * Run your Genetic Algorithm to evolve new embeddings.
# * Analyze and visualize the newly inserted words.

# %%
# =============================================================================
# SETUP & IMPORTS
# =============================================================================
import os
import random
import numpy as np
import torch

# --- Imports from Previous Labs ---
# We rely on text processing tools from Lab 2 and Lab 6
from src.lab2 import process_text_network
from src.lab6_current_best import (
    prepare_visual_genome_text,
    filter_punctuation_from_network,
    analyze_embeddings,
    find_similar_words
)

# --- Imports for Lab 7 (Genetic Algorithm) ---
# These functions handle the core Evolutionary Strategy logic,
# data loading for CIFAR-100, and visualization tools.
from src.lab7 import (
    load_trained_model,
    create_mappings,
    compute_embedding_stats,
    get_cifar100_vocabulary,
    analyze_vocabulary_overlap,
    extract_word_contexts,
    evolve_embedding,           # <--- The core GA function you will implement/use
    visualize_with_inserted_words,
    run_sanity_checks
)

# %%
# =============================================================================
# CONFIGURATION & HYPERPARAMETERS
# =============================================================================
# This cell defines all the key parameters for our experiment.
#
# -----------------------------------------------------------------------------
# 📖 TUNING NOTE:
# The `ga_...` parameters and `fitness_weights` are the most
# interesting ones to experiment with. Small changes here can
# significantly alter the final position and quality of the
# inserted embeddings.
# -----------------------------------------------------------------------------


# --- 1. File & Data Paths ---
# Defines where to load the pre-trained model from and where to find
# the corpus text data.
model_path = 'best_model.pth'
text_file = 'vg_text.txt'
zip_url = "https://homes.cs.washington.edu/~ranjay/visualgenome/data/dataset/region_descriptions.json.zip"

# --- 2. Pre-trained Model Parameters ---
# These parameters MUST match the architecture of the 'baseline_model.pth'
# that we are loading.
rare_threshold = 0.00025    # Filtering threshold used to train the model
embedding_dim = 96         # Dimensionality of the embedding vectors
dropout = 0.3              # Dropout rate of the loaded model
punctuation_tokens = {'.', ',', '<RARE>', "'"} # Tokens to ignore

# --- 4. Genetic Algorithm (ES) Parameters ---
context_window = 5         # (Window for context extraction, from Lab 6)

ga_pop_size = 100          # Population size (λ in 1+λ).
                           # We create 100 "offspring" per generation.
ga_generations = 300       # Number of evolutionary cycles to run.
ga_mutation_factor = 0.05  # The "step size" of the mutation. This is
                           # scaled by the embedding space's global
                           # standard deviation.

# --- 5. Fitness Function Weights ---
# **This is the most critical part!**
# These weights define the "goal" of the evolution. They control the
# trade-off between the three parts of our fitness function.
fitness_weights = {
    # 60% priority: Fit the corpus (Skip-Gram objective).
    'corpus': 0.70,

    # 15% priority: Match the "shape" of the space.
    # (i.e., new vectors should have a similar norm/length).
    'norm': 0.15,

    # 25% priority: Be close to our semantic anchors.
    'anchor': 0.15 #0.15
}

print("✓ All configurations set.")
print(f"  GA Config: {ga_pop_size} population, {ga_generations} generations")
print(f"  Fitness Weights: Corpus={fitness_weights['corpus']}, "
      f"Norm={fitness_weights['norm']}, "
      f"Anchor={fitness_weights['anchor']}")
# Out:
# ✓ All configurations set.
#   GA Config: 100 population, 300 generations
#   Fitness Weights: Corpus=0.7, Norm=0.15, Anchor=0.15

# %%
# =============================================================================
# STAGE 1: LOAD CORPUS & BUILD VOCABULARY
# =============================================================================
# In this stage, we load the raw text corpus (Visual Genome) and process
# it to exactly match the vocabulary used to train our baseline model.
#
# We need this vocabulary ('nodes') to:
# 1. Load the pre-trained model (which requires the 'vocab_size').
# 2. Create the 'word_to_idx' and 'idx_to_word' mappings.
# 3. Extract contexts for our new words.

print("\n[STAGE 1] Loading Data & Building Vocabulary")
print("-" * 70)

# --- 1. Download or load text data ---
# We use the Visual Genome dataset as our corpus.
if not os.path.exists(text_file):
    print(f"Text file not found. Downloading corpus from {zip_url}...")
    # This function (from lab6) downloads, extracts, and cleans the text.
    text_file = prepare_visual_genome_text(
        zip_url=zip_url,
        zip_path="region_descriptions.json.zip",
        json_path="region_descriptions.json",
        output_path=text_file
    )
else:
    print(f"✓ Text file '{text_file}' already exists.")

# --- 2. Build co-occurrence network ---
# This step (from lab2) processes the entire text file, counts word
# frequencies, filters rare words, and builds the co-occurrence network.
print("\nProcessing text to build co-occurrence network...")
network_data = process_text_network(
    text_file,
    rare_threshold=rare_threshold,  # Must match the model's training
    rare_token="<RARE>",
    distance_mode="inverted",
    verbose=True  # Set to True to see progress
)


# --- 3. Filter punctuation ---
# We clean up the network by removing punctuation tokens.
network_data = filter_punctuation_from_network(
    network_data,
    punctuation_tokens=punctuation_tokens
)

# --- 4. Finalize Vocabulary ---
# The 'nodes' list from the network IS our final vocabulary.
nodes = network_data['nodes']
vocab_size = len(nodes)



print(f"\n{'-'*70}")
print(f"✓ STAGE 1 Complete: Vocabulary built.")
print(f"  Total vocabulary size (Vocab Size): {vocab_size} nodes")
print(f"  Total graph edges: {network_data['graph'].number_of_edges():,}")
# Out:
# [STAGE 1] Loading Data & Building Vocabulary
# ----------------------------------------------------------------------
# ✓ Text file 'vg_text.txt' already exists.
#
# Processing text to build co-occurrence network...
# Loaded text: 154199868 characters
# Tokenized: 27533256 tokens
# Sample tokens: ['wlall', 'awi', 'walks', 'refloor', 'keysia', 'leyboard', 'enhibit', 'adelaida', 'elights', 'referre', 'beacch', 'johann', 'stackd', 'chartreuse', 'clu', 'eric', 'moody', 'toeach', 'graffit', 'novak']
# Replaced 62380 rare tokens (threshold=0.00025)
# Final vocabulary: 456 unique tokens
# Sample tokens: ['between', 'player', 'picture', 'couch', 'windshield', 'stone', 'striped', 'many', 'boat', 'pair', 'flowers', 'people', 'mouse', 'chain', 'wearing', 'pants', 'eyes', 'bowl', 'teddy', 'bed']
# Graph: 456 nodes, 84581 edges
# Top tokens by frequency:
#    1. '<RARE>' (freq=4416304)
#    2. 'a' (freq=2220903)
#    3. 'the' (freq=2155082)
#    4. 'on' (freq=1396037)
#    5. 'of' (freq=980462)
#    6. 'is' (freq=787911)
#    7. 'in' (freq=714868)
#    8. 'white' (freq=652421)
#    9. 'black' (freq=398632)
#   10. 'and' (freq=341934)
#
# 🔧 PUNCTUATION FILTER:
#   Removed: {'<RARE>', ',', '.', "'"}
#   Nodes: 456 → 455
#   Edges: 84,581 → 84,126
#
# ----------------------------------------------------------------------
# ✓ STAGE 1 Complete: Vocabulary built.
#   Total vocabulary size (Vocab Size): 455 nodes
#   Total graph edges: 84,126

# %%
import math
import re
from collections import Counter
from typing import Dict, Set, Optional


DEFAULT_STOPWORDS = {
    "a","an","the","and","or","but","if","then","else","when","while",
    "to","of","in","on","at","by","for","with","about","against","between",
    "into","through","during","before","after","above","below","from","up","down",
    "out","over","under","again","further","once",
    "is","am","are","was","were","be","been","being",
    "have","has","had","do","does","did",
    "it","its","it's","this","that","these","those",
    "he","him","his","she","her","hers","they","them","their","theirs",
    "i","me","my","mine","we","us","our","ours","you","your","yours",
    "as","not","no","nor","so","too","very","can","could","should","would","will","just",
    "there","here","than","such"
}


def compute_idf_from_vg_text(
    vg_text_path: str,
    vocab: Optional[Set[str]] = None,
    smooth: bool = True
) -> Dict[str, float]:
    """
    Compute IDF scores using the SAME tokenizer as extract_word_contexts:
    regex: r'\\b[a-z]+\\b'
    
    Each line is treated as a document (same assumption as extract_word_contexts).
    """

    df = Counter()
    N = 0
    vocab_set = set(vocab) if vocab is not None else None

    with open(vg_text_path, "r", encoding="utf-8") as f:
        for line in f:
            tokens = re.findall(r'\b[a-z]+\b', line.lower())
            if not tokens:
                continue

            if vocab_set is not None:
                doc_terms = set(t for t in tokens if t in vocab_set)
            else:
                doc_terms = set(tokens)

            if not doc_terms:
                continue

            N += 1
            for t in doc_terms:
                df[t] += 1

    if N == 0:
        return {}

    idf = {}
    if smooth:
        for t, dft in df.items():
            idf[t] = math.log((N + 1.0) / (dft + 1.0)) + 1.0
    else:
        for t, dft in df.items():
            idf[t] = math.log(N / float(dft))

    return idf

# %%
# =============================================================================
# STAGE 2: LOAD PRE-TRAINED MODEL & COMPUTE STATS
# =============================================================================
# Now we load the Skip-Gram model that was trained on the vocabulary we
# just built. We also compute the vital statistics of this embedding space.

print("\n[STAGE 2] Loading Model & Analyzing Embedding Space")
print("-" * 70)

# --- 1. Load Model & Embeddings ---
# This function loads the .pth file, initializes the SkipGramModel
# with the *exact* same architecture, and loads the trained weights.
# It then extracts the final (input) embedding matrix as a NumPy array.
model, embeddings = load_trained_model(
    model_path=model_path,
    vocab_size=vocab_size,
    embedding_dim=embedding_dim,
    dropout=dropout
)

# --- 2. Create Mappings ---
# We need fast lookups between words and their corresponding index
# in the embedding matrix.
word_to_idx, idx_to_word = create_mappings(nodes)

# --- 3. Compute Embedding Space Statistics ---
# **Crucial Step for the GA:** We compute the statistics of the *existing*
# embedding space. Our fitness function will use these values to
# ensure that new, evolved vectors "fit in" with the original vectors.
#
# - 'mean_norm': The average length (L2 norm) of all existing vectors.
# - 'std_norm': The standard deviation of the vector lengths.
# - 'global_std': The standard deviation of *all* embedding values.
#                 (Used to scale the GA's mutation strength).
embedding_stats = compute_embedding_stats(embeddings)

print(f"\n{'-'*70}")
print(f"✓ STAGE 2 Complete: Model loaded and stats computed.")
print(f"  Embedding matrix shape: {embeddings.shape}")
print(f"  Key Stats for Fitness Function:")
print(f"    ├─ Mean Vector Norm: {embedding_stats['mean_norm']:.4f}")
print(f"    ├─ Std. Dev of Norms: {embedding_stats['std_norm']:.4f}")
print(f"    └─ Global Std. Dev: {embedding_stats['global_std']:.4f} (for mutation)")
# Out:
# [STAGE 2] Loading Model & Analyzing Embedding Space
# ----------------------------------------------------------------------
# ✓ Loaded model: 455 embeddings, dim=96
#
# ----------------------------------------------------------------------
# ✓ STAGE 2 Complete: Model loaded and stats computed.
#   Embedding matrix shape: (455, 96)
#   Key Stats for Fitness Function:
#     ├─ Mean Vector Norm: 1.7074
#     ├─ Std. Dev of Norms: 0.3664
#     └─ Global Std. Dev: 0.1782 (for mutation)

# %%
#CLEAN ANCHORS

import numpy as np
from typing import Dict, List, Tuple, Optional

def _l2_normalize(mat: np.ndarray, eps: float = 1e-10) -> np.ndarray:
    return mat / (np.linalg.norm(mat, axis=1, keepdims=True) + eps)

def clean_anchors_for_word(
    word: str,
    anchors: Dict[str, List[str]],
    embeddings: np.ndarray,
    word_to_idx: Dict[str, int],
    lambda_mad: float = 1.5,
    k_min: int = 2,
    verbose: bool = False
) -> Tuple[List[str], Dict[str, float]]:
    """
    Returns:
      cleaned_anchors: list of anchors kept for `word`
      scores: coherence score per anchor (median cosine to other anchors)
    """
    cand = anchors.get(word, [])
    cand = [a for a in cand if a in word_to_idx]
    if len(cand) <= 2:
        # nothing meaningful to clean
        scores = {a: 1.0 for a in cand}
        return cand, scores

    # Build normalized anchor matrix
    A = np.array([embeddings[word_to_idx[a]] for a in cand], dtype=np.float32)
    A = _l2_normalize(A)

    # Pairwise cosine matrix
    S = A @ A.T  # (m, m)
    m = S.shape[0]

    # coherence score per anchor = median cosine to others
    scores_list = []
    for i in range(m):
        others = np.concatenate([S[i, :i], S[i, i+1:]])
        scores_list.append(float(np.median(others)))

    scores = {cand[i]: scores_list[i] for i in range(m)}

    # Robust threshold using MAD
    med = float(np.median(scores_list))
    mad = float(np.median(np.abs(np.array(scores_list) - med)))
    mad = max(mad, 0.01) 
    thr = med - lambda_mad * mad

    kept = [a for a, sc in scores.items() if sc >= thr]

    # Fallback: keep top-k_min by score if too few
    if len(kept) < k_min:
        kept = sorted(scores.keys(), key=lambda a: scores[a], reverse=True)[:k_min]

    if verbose:
        removed = [a for a in cand if a not in kept]
        print(f"[anchor-clean] {word}: kept={kept}, removed={removed}")
        print(f"  scores={ {a: round(scores[a], 3) for a in cand} }")
        print(f"  med={med:.3f}, mad={mad:.3f}, thr={thr:.3f}")

    return kept, scores

# %%
# =============================================================================
# STAGE 3: SANITY CHECKS (VERIFICATION)
# =============================================================================
# Before we start the complex GA process, let's verify that the model
# we loaded is sane and produces reasonable results.
#
# This function will:
# 1. Check model properties (e.g., it's in eval mode).
# 2. Check embedding matrix stats (e.g., no NaNs/Infs).
# 3. Print nearest neighbors for a few common words ('man', 'dog', etc.)
#    using the `find_similar_words` function from Lab 6.
#
# If the neighbors look sensible, our embedding space is good!

run_sanity_checks(model, embeddings, nodes, word_to_idx)
# Out:
# ======================================================================
# SANITY CHECKS
# ======================================================================
#
# 1. Model Configuration:
#    Training mode: False
#    Device: cpu
#
# 2. Embedding Quality:
#    Shape: (455, 96)
#    Mean: -0.001574, Std: 0.178225
#    Min: -0.877702, Max: 0.860647
#    Contains NaN: False, Contains Inf: False
#
# 3. Embedding Norms:
#    Mean: 1.7074, Std: 0.3664
#    Range: [1.2575, 3.1674]
#
# 4. Vocabulary Test:
#    'man       ' → idx=   9, norm=1.4181
#       Similar: woman(0.955), person(0.943), guy(0.923), lady(0.910), boy(0.889)
#    'woman     ' → idx=  19, norm=1.4987
#       Similar: man(0.955), lady(0.950), guy(0.947), person(0.936), girl(0.934)
#    'dog       ' → idx=  64, norm=1.5306
#       Similar: bear(0.936), cat(0.918), animal(0.913), cow(0.894), horse(0.886)
#    'car       ' → idx=  45, norm=1.5639
#       Similar: vehicle(0.967), van(0.954), truck(0.938), bus(0.931), train(0.911)
#    'blue      ' → idx=  11, norm=1.3646
#       Similar: red(0.934), white(0.931), purple(0.907), yellow(0.906), colorful(0.906)
#
# ======================================================================
# ✓ SANITY CHECKS COMPLETE
# ======================================================================

# %%
# =============================================================================
# STAGE 4: DEFINE TARGET WORDS
# =============================================================================
# Our goal is to insert new words. But *which* words?
#
# This notebook is set up for two potential experiments:
# 1. Insert a small, manually-defined list ('wolf', 'tiger', etc.)
# 2. Insert all the words from CIFAR-100 that are missing from our vocab.
#
# For this lab, we will do a mix: we'll load the CIFAR-100 list to
# perform an analysis, but our *actual* target list for the GA
# will be the small, manual list we defined in the config cell.
# This lets us test the algorithm quickly on a few interesting words.

print("\n[STAGE 4] Vocabulary Analysis & Target Selection")
print("-" * 70)

# --- 1. Analysis: Compare against CIFAR-100 ---
# Let's see how many CIFAR-100 class names are missing from our
# Visual Genome vocabulary.
cifar_vocab = get_cifar100_vocabulary()

# This function prints a detailed analysis and returns the list of
# words that are in CIFAR-100 but NOT in our 'nodes' (model vocab).
missing_cifar_words = analyze_vocabulary_overlap(cifar_vocab, nodes)
# Out:
# [STAGE 4] Vocabulary Analysis & Target Selection
# ----------------------------------------------------------------------
#
# Loading CIFAR-100 vocabulary...
# ✓ CIFAR-100 vocabulary loaded: 100 classes
#
# ======================================================================
# VOCABULARY OVERLAP ANALYSIS
# ======================================================================
# CIFAR-100 vocabulary: 100 classes
# Network vocabulary: 455 words
# Overlapping words: 32 (32.0%)
# Missing from network: 68
#
# Found: apple, baby, bear, bed, bicycle, bottle, bowl, boy, bridge, bus, can, chair, clock, cloud, couch, cup, elephant, girl, house, keyboard, lamp, man, motorcycle, mountain, mouse, orange, plate, road, table, tank, train, woman
#
# Missing: aquarium_fish, beaver, bee, beetle, butterfly, camel, castle, caterpillar, cattle, chimpanzee, cockroach, crab, crocodile, dinosaur, dolphin, flatfish, forest, fox, hamster, kangaroo, lawn_mower, leopard, lion, lizard, lobster, maple_tree, mushroom, oak_tree, orchid, otter, palm_tree, pear, pickup_truck, pine_tree, plain, poppy, porcupine, possum, rabbit, raccoon, ray, rocket, rose, sea, seal, shark, shrew, skunk, skyscraper, snail, snake, spider, squirrel, streetcar, sunflower, sweet_pepper, telephone, television, tiger, tractor, trout, tulip, turtle, wardrobe, whale, willow_tree, wolf, worm
# ======================================================================

# %%
## ΘΕΛΩ ΝΑ ΔΩ ΠΟΙΕΣ ΛΕΞΕΙΣ ΛΕΙΠΟΥΝΕ ΚΑΙ ΠΟΣΕΣ ΕΙΝΑΙ.
print(missing_cifar_words)
print(len(missing_cifar_words))
# Out:
# ['aquarium_fish', 'beaver', 'bee', 'beetle', 'butterfly', 'camel', 'castle', 'caterpillar', 'cattle', 'chimpanzee', 'cockroach', 'crab', 'crocodile', 'dinosaur', 'dolphin', 'flatfish', 'forest', 'fox', 'hamster', 'kangaroo', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'maple_tree', 'mushroom', 'oak_tree', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'telephone', 'television', 'tiger', 'tractor', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'worm']
# 68

# %%
# =============================================================================
# STAGE 5: EXTRACT CORPUS CONTEXTS
# =============================================================================
# This is a critical data-gathering step for our Genetic Algorithm.
#
# To evaluate the 'corpus' part of our fitness function, we need to
# know which words our new target words co-occur with in the text.
#
# This function will read the entire 'vg_text.txt' corpus and find
# all co-occurrences for our 'target_words' within the specified window.
#
# It returns a dictionary, e.g.:
# contexts = {
#     'wolf': Counter({'animal': 12, 'forest': 8, ...}),
#     'tiger': Counter({'stripes': 20, 'cat': 15, ...})
# }
#
# This Counter will be used to select the positive samples (ctx_vecs)
# in the fitness function.

# We need the 'set(nodes)' to quickly check if a context word is
# actually in our vocabulary. We ignore any context words that aren't.
vocab_set = set(nodes)

idf = compute_idf_from_vg_text(
    vg_text_path=text_file,
    vocab=vocab_set
)

  # αρχική conservative τιμή

print(idf["man"])
# Out:
# 1.7524530945187917

# %%
idf_threshold = 1.65

IDF_EXEMPT = {
    # 0 contexts
    "flatfish",
    "possum",
    "shrew",

    # very low contexts (<=10)
    "aquarium_fish",
    "skunk",
    "sweet_pepper",

    # low contexts (<=30)
    "cockroach",
    "porcupine",
    "trout",

    # borderline / phrase-based / sparse
    "chimpanzee",
    "maple_tree",
    "lawn_mower",
    "caterpillar",
    "snail",
    "worm"
}

contexts = extract_word_contexts(
    text_file=text_file,
    target_words=missing_cifar_words,
    vocab_set=vocab_set,
    window=context_window,
    stopwords=DEFAULT_STOPWORDS,
    idf = idf,
    idf_threshold = 1.8,
    idf_exempt_targets = IDF_EXEMPT
)

print(f"\n{'-'*70}")
print("✓ STAGE 5 Complete: Contexts extracted.")
# Out:
#  Complete
#
# Context statistics:
#     aquarium_fish  :      7 contexts,   7 unique words
#     beaver         :    164 contexts,  69 unique words
#     bee            :    226 contexts,  92 unique words
#     beetle         :    219 contexts,  85 unique words
#     butterfly      :   2179 contexts, 284 unique words
#     camel          :    634 contexts, 175 unique words
#     castle         :   2470 contexts, 271 unique words
#     caterpillar    :    127 contexts,  59 unique words
#     cattle         :   2498 contexts, 248 unique words
#     chimpanzee     :     57 contexts,  23 unique words
#     cockroach      :     27 contexts,  15 unique words
#     crab           :    552 contexts, 160 unique words
#     crocodile      :    113 contexts,  62 unique words
#     dinosaur       :    747 contexts, 188 unique words
#     dolphin        :    415 contexts, 136 unique words
#     flatfish       :      0 contexts,   0 unique words
#     forest         :  13789 contexts, 377 unique words
#     fox            :    436 contexts, 161 unique words
#     hamster        :    287 contexts,  63 unique words
#     kangaroo       :    280 contexts, 109 unique words
#     lawn_mower     :     89 contexts,  59 unique words
#     leopard        :    715 contexts, 205 unique words
#     lion           :   1949 contexts, 280 unique words
#     lizard         :    415 contexts, 135 unique words
#     lobster        :    400 contexts, 141 unique words
#     maple_tree     :     67 contexts,  45 unique words
#     mushroom       :   3084 contexts, 235 unique words
#     oak_tree       :    147 contexts,  80 unique words
#     orchid         :    232 contexts,  86 unique words
#     otter          :    145 contexts,  40 unique words
#     palm_tree      :  11055 contexts, 371 unique words
#     pear           :    865 contexts, 169 unique words
#     pickup_truck   :   3553 contexts, 296 unique words
#     pine_tree      :   6835 contexts, 339 unique words
#     plain          :   6148 contexts, 387 unique words
#     poppy          :    202 contexts,  74 unique words
#     porcupine      :     30 contexts,  19 unique words
#     possum         :      0 contexts,   0 unique words
#     rabbit         :   1215 contexts, 229 unique words
#     raccoon        :     86 contexts,  58 unique words
#     ray            :    388 contexts, 171 unique words
#     rocket         :    341 contexts, 135 unique words
#     rose           :   5014 contexts, 336 unique words
#     sea            :  11215 contexts, 361 unique words
#     seal           :   1174 contexts, 236 unique words
#     shark          :    601 contexts, 162 unique words
#     shrew          :      0 contexts,   0 unique words
#     skunk          :     10 contexts,  10 unique words
#     skyscraper     :   2590 contexts, 252 unique words
#     snail          :    146 contexts,  63 unique words
#     snake          :    318 contexts, 147 unique words
#     spider         :    439 contexts, 178 unique words
#     squirrel       :   1155 contexts, 157 unique words
#     streetcar      :    132 contexts,  65 unique words
#     sunflower      :    758 contexts, 195 unique words
#     sweet_pepper   :     18 contexts,  12 unique words
#     telephone      :  15122 contexts, 389 unique words
#     television     :  21182 contexts, 378 unique words
#     tiger          :   1544 contexts, 242 unique words
#     tractor        :   2154 contexts, 276 unique words
#     trout          :     29 contexts,  20 unique words
#     tulip          :    492 contexts, 130 unique words
#     turtle         :    493 contexts, 168 unique words
#     wardrobe       :    335 contexts, 113 unique words
#     whale          :    309 contexts, 119 unique words
#     willow_tree    :    207 contexts,  88 unique words
#     wolf           :    258 contexts, 117 unique words
#     worm           :    134 contexts,  68 unique words
#
# ----------------------------------------------------------------------
# ✓ STAGE 5 Complete: Contexts extracted.

# %%
anchors = {
    # =====================
    # context < 100 → 8
    # =====================

    "aquarium_fish": [
        "water", "ocean", "waves", "beach", "boat", "sand"
    ],

    "chimpanzee": [
        "animal", "face", "eyes", "mouth", "hands", "arm", "body", "hair"
    ],

    "cockroach": [
        "bug", "legs", "floor", "trash", "ground", "dirt"
    ],

    "maple_tree": [
        "trees", "branches", "leaf", "leaves", "trunks", "grass", "ground", "growing"
    ],

    "lawn_mower": [
        "grass", "ground", "wheels", "engine", "metal", "pushes", "dirt", "parked"
    ],

    "porcupine": [
        "animal", "furry", "tail", "legs", "bushes", "trees"
    ],

    "raccoon": [
        "animal", "furry", "tail", "ears", "eyes", "face", "ground", "trees"
    ],

    "skunk": [
        "animal", "furry", "tail", "legs", "ground", "bushes", "trees", "dirt"
    ],

    "sweet_pepper": [
        "broccoli", "food", "plate", "bowl", "knife", "fork", "sandwich", "cheese"
    ],

    "trout": [
        "boat", "water", "ocean", "waves", "beach", "sand", "plate", "knife"
    ],

    # =====================
    # context = 0 → 10
    # =====================

    "flatfish": [
        "ocean", "water", "sand", "bottom", "under",
        "rocks", "covered", "shadow", "deep", "ground"
    ],

    "possum": [
        "animal", "furry", "tail", "legs", "ears",
        "nose", "ground", "bushes", "trees", "branches"
    ],

    "shrew": [
        "animal", "furry", "nose", "ears", "legs",
        "ground", "grass", "dirt", "bushes", "branches"
    ],

    # =====================
    # context > 100 → 5
    # =====================

    "beaver": [
        "animal", "tail", "water", "trees", "branches"
    ],

    "bee": [
        "bug", "flying", "flowers"
    ],

    "beetle": [
        "bug", "trees", "branches"
    ],

    "butterfly": [
        "wing", "flying", "flowers", "colored", "plant"
    ],

    "camel": [
        "animal", "horse", "sand", "ground", "tail"
    ],

    "castle": [
        "building", "tower", "windows", "wall", "bridge"
    ],

    "caterpillar": [
        "bug", "leaf", "leaves", "branches", "plant"
    ],

    "cattle": [
        "cow", "horses", "grass", "field", "animal"
    ],

    "crab": [
        "legs", "rocks", "sand", "beach", "water"
    ],

    "crocodile": [
        "animal", "tail", "legs", "mouth", "water"
    ],

    "dinosaur": [
        "animal", "tail", "legs", "head", "body"
    ],

    "dolphin": [
        "swimming", "waves", "water", "ocean", "surfboard"
    ],

    "forest": [
        "trees", "branches", "leaves", "grass", "dirt"
    ],

    "fox": [
        "animal", "dog", "tail", "furry", "ears"
    ],

    "hamster": [
        "animal", "furry", "ears", "legs", "ground"
    ],

    "kangaroo": [
        "animal", "legs", "tail", "ground", "standing"
    ],

    "leopard": [
        "cat", "spot", "furry", "tail", "legs"
    ],

    "lion": [
        "cat", "furry", "tail", "face", "legs"
    ],

    "lizard": [
        "animal", "tail", "legs", "head", "ground"
    ],

    "lobster": [
        "plate", "knife", "food", "restaurant", "ocean"
    ],

    "mushroom": [
        "ground", "dirt", "wet", "grass", "plant"
    ],

    "oak_tree": [
        "trees", "branches", "trunks", "leaves", "grass"
    ],

    "orchid": [
        "flowers", "colored", "pink", "green", "vase"
    ],

    "otter": [
        "animal", "water", "ocean", "furry", "tail"
    ],

    "palm_tree": [
        "beach", "sand", "ocean", "sky", "trees"
    ],

    "pear": [
        "fruit", "apple", "bananas", "bowl", "basket"
    ],

    "pickup_truck": [
        "truck", "wheels", "engine", "license", "parked"
    ],

    "pine_tree": [
        "trees", "branches", "trunks", "grass", "mountain"
    ],

    "plain": [
        "grass", "field", "ground", "sky", "clouds"
    ],

    "poppy": [
        "flowers", "colored", "grass", "field", "green"
    ],

    "rabbit": [
        "animal", "ears", "tail", "legs", "furry"
    ],

    "ray": [
        "wing", "sand", "bottom", "shadow", "ocean"
    ],

    "rocket": [
        "sky", "engine", "metal", "air","airplane", "jet"
    ],

    "rose": [
        "flowers", "pink", "vase", "green", "plant"
    ],

    "sea": [
        "ocean", "waves", "sky", "beach", "boat"
    ],

    "seal": [
        "beach", "sand", "wet", "furry", "rocks"
    ],

    "shark": [
        "teeth", "mouth", "tail", "under", "ocean"
    ],

    "skyscraper": [
        "building", "tower", "windows", "street", "lights"
    ],

    "snail": [
        "ground", "grass", "leaf", "wet", "bug"
    ],

    "snake": [
        "animal", "body", "head", "tail", "ground"
    ],

    "spider": [
        "bug", "legs", "ground", "branches"
    ],

    "squirrel": [
        "animal", "tail", "furry", "trees", "branches"
    ],

    "streetcar": [
        "train", "bus", "street", "track", "wheels"
    ],

    "sunflower": [
        "flowers", "yellow", "green", "field", "sky"
    ],

    "telephone": [
        "phone", "cell", "computer", "monitor", "keyboard"
    ],

    "television": [
        "tv", "remote", "monitor", "computer", "desk"
    ],

    "tiger": [
        "cat", "striped", "furry", "tail", "legs"
    ],

    "tractor": [
        "vehicle", "wheels", "engine", "dirt", "field"
    ],

    "tulip": [
        "flowers", "colored", "vase", "plant", "green"
    ],

    "turtle": [
        "sand", "beach", "water", "legs", "head"
    ],

    "wardrobe": [
        "shirt", "pants", "jacket", "shoes", "suitcase"
    ],

    "whale": [
        "sea", "waves", "boat", "sky", "ocean"
    ],

    "willow_tree": [
        "trees", "branches", "leaves", "water", "grass"
    ],

    "wolf": [
        "animal", "dog", "tail", "legs", "furry"
    ],

    "worm": [
        "ground", "dirt", "grass", "plant", "bug"
    ],
}


# =====================
# PATCH ONLY: problematic anchors
# =====================

anchors.update({

    # ---- aquatic cluster is too "beach/sea" dominated ----
    # aquarium_fish was glued to sea/whale/palm_tree
    # Add "fish" + container-ish tokens that exist in your vocab (container shows up in report),
    # and REMOVE some beach-only pull.
    "aquarium_fish": [
        "fish", "water", "ocean", "waves", "container", "bowl", "glass", "tank"
    ],

    # palm_tree was essentially "sea/beach" so it becomes sea-like.
    # Remove sea/ocean/beach/sand pull and make it TREE-like.
    "palm_tree": [
        "trees", "tree", "trunks", "branches", "leaves"
    ],

    # whale/sea glue is expected, but palm_tree being pulled there is not.
    # (No need to change sea/whale unless you want to reduce their similarity too.)

    # ---- animals collapsing into one blob ----
    # beaver was glued to squirrel/forest. Make it more "wood/wet" and less generic forest.
    "beaver": [
        "animal", "tail", "water", "wet", "wooden"
    ],

    # camel was ending up near reptiles/rodents. Push it back toward large mammals/hoofed.
    "camel": [
        "animal", "horse", "cow", "zebra", "giraffes"
    ],

    # shark was drifting toward snake/crocodile due to body-part anchors.
    # Keep one body cue + make it clearly aquatic.
    "shark": [
        "ocean", "water", "waves", "teeth", "tail"
    ],

    # ---- insects being pulled into plants/air/design ----
    # bee was near "air/design/lines". Anchor it to flowers cluster deliberately.
    "bee": [
        "bug", "wing", "flowers", "sunflower", "poppy"
    ],

    # beetle was anchored to trees/branches so it became a tree.
    # Pull it to "bug/ground/legs" instead (closer to cockroach/spider/worm side).
    "beetle": [
        "bug", "legs", "ground", "dirt", "spider"
    ],
})

# keep your filter
for w in anchors:
    anchors[w] = [a for a in anchors[w] if a in word_to_idx]

# %%
print(anchors)
missing = {}
for w, lst in anchors.items():
    miss = [a for a in lst if a not in word_to_idx]
    if miss:
        missing[w] = miss

print(missing)

print(contexts)


for w, arr in anchors.items():
    if w in {"aquarium_fish","palm_tree","beaver","camel","shark","bee","beetle"}:
        print(w, len(arr), arr)
# Out:
# {'aquarium_fish': ['water', 'ocean', 'waves', 'container', 'bowl', 'glass', 'tank'], 'chimpanzee': ['animal', 'face', 'eyes', 'mouth', 'hands', 'arm', 'body', 'hair'], 'cockroach': ['legs', 'floor', 'trash', 'ground', 'dirt'], 'maple_tree': ['trees', 'branches', 'leaf', 'leaves', 'grass', 'ground', 'growing'], 'lawn_mower': ['grass', 'ground', 'wheels', 'engine', 'metal', 'dirt', 'parked'], 'porcupine': ['animal', 'tail', 'legs', 'bushes', 'trees'], 'raccoon': ['animal', 'tail', 'ears', 'eyes', 'face', 'ground', 'trees'], 'skunk': ['animal', 'tail', 'legs', 'ground', 'bushes', 'trees', 'dirt'], 'sweet_pepper': ['broccoli', 'food', 'plate', 'bowl', 'knife', 'fork', 'sandwich', 'cheese'], 'trout': ['boat', 'water', 'ocean', 'waves', 'beach', 'sand', 'plate', 'knife'], 'flatfish': ['ocean', 'water', 'sand', 'bottom', 'under', 'rocks', 'covered', 'shadow', 'ground'], 'possum': ['animal', 'tail', 'legs', 'ears', 'nose', 'ground', 'bushes', 'trees', 'branches'], 'shrew': ['animal', 'nose', 'ears', 'legs', 'ground', 'grass', 'dirt', 'bushes', 'branches'], 'beaver': ['animal', 'tail', 'water', 'wet', 'wooden'], 'bee': ['wing', 'flowers'], 'beetle': ['legs', 'ground', 'dirt'], 'butterfly': ['wing', 'flying', 'flowers', 'colored', 'plant'], 'camel': ['animal', 'horse', 'cow', 'zebra', 'giraffes'], 'castle': ['building', 'tower', 'windows', 'wall', 'bridge'], 'caterpillar': ['leaf', 'leaves', 'branches', 'plant'], 'cattle': ['cow', 'horses', 'grass', 'field', 'animal'], 'crab': ['legs', 'rocks', 'sand', 'beach', 'water'], 'crocodile': ['animal', 'tail', 'legs', 'mouth', 'water'], 'dinosaur': ['animal', 'tail', 'legs', 'head', 'body'], 'dolphin': ['waves', 'water', 'ocean', 'surfboard'], 'forest': ['trees', 'branches', 'leaves', 'grass', 'dirt'], 'fox': ['animal', 'dog', 'tail', 'ears'], 'hamster': ['animal', 'ears', 'legs', 'ground'], 'kangaroo': ['animal', 'legs', 'tail', 'ground', 'standing'], 'leopard': ['cat', 'spot', 'tail', 'legs'], 'lion': ['cat', 'tail', 'face', 'legs'], 'lizard': ['animal', 'tail', 'legs', 'head', 'ground'], 'lobster': ['plate', 'knife', 'food', 'ocean'], 'mushroom': ['ground', 'dirt', 'wet', 'grass', 'plant'], 'oak_tree': ['trees', 'branches', 'leaves', 'grass'], 'orchid': ['flowers', 'colored', 'pink', 'green', 'vase'], 'otter': ['animal', 'water', 'ocean', 'tail'], 'palm_tree': ['trees', 'tree', 'branches', 'leaves'], 'pear': ['fruit', 'apple', 'bananas', 'bowl', 'basket'], 'pickup_truck': ['truck', 'wheels', 'engine', 'license', 'parked'], 'pine_tree': ['trees', 'branches', 'grass', 'mountain'], 'plain': ['grass', 'field', 'ground', 'sky', 'clouds'], 'poppy': ['flowers', 'colored', 'grass', 'field', 'green'], 'rabbit': ['animal', 'ears', 'tail', 'legs'], 'ray': ['wing', 'sand', 'bottom', 'shadow', 'ocean'], 'rocket': ['sky', 'engine', 'metal', 'air', 'airplane', 'jet'], 'rose': ['flowers', 'pink', 'vase', 'green', 'plant'], 'sea': ['ocean', 'waves', 'sky', 'beach', 'boat'], 'seal': ['beach', 'sand', 'wet', 'rocks'], 'shark': ['ocean', 'water', 'waves', 'tail'], 'skyscraper': ['building', 'tower', 'windows', 'street', 'lights'], 'snail': ['ground', 'grass', 'leaf', 'wet'], 'snake': ['animal', 'body', 'head', 'tail', 'ground'], 'spider': ['legs', 'ground', 'branches'], 'squirrel': ['animal', 'tail', 'trees', 'branches'], 'streetcar': ['train', 'bus', 'street', 'track', 'wheels'], 'sunflower': ['flowers', 'yellow', 'green', 'field', 'sky'], 'telephone': ['phone', 'cell', 'computer', 'monitor', 'keyboard'], 'television': ['tv', 'remote', 'monitor', 'computer', 'desk'], 'tiger': ['cat', 'striped', 'tail', 'legs'], 'tractor': ['vehicle', 'wheels', 'engine', 'dirt', 'field'], 'tulip': ['flowers', 'colored', 'vase', 'plant', 'green'], 'turtle': ['sand', 'beach', 'water', 'legs', 'head'], 'wardrobe': ['shirt', 'pants', 'jacket', 'shoes', 'suitcase'], 'whale': ['waves', 'boat', 'sky', 'ocean'], 'willow_tree': ['trees', 'branches', 'leaves', 'water', 'grass'], 'wolf': ['animal', 'dog', 'tail', 'legs'], 'worm': ['ground ...
# {}
# {'aquarium_fish': Counter({'building': 1, 'wall': 1, 'light': 1, 'top': 1, 'tank': 1, 'bathroom': 1, 'toilet': 1}), 'beaver': Counter({'sign': 13, 'frisbee': 8, 'eyes': 7, 'nose': 6, 'holding': 5, 'tree': 5, 'tail': 5, 'animal': 4, 'stop': 4, 'small': 3, 'person': 3, 'people': 3, 'branch': 3, 'painted': 3, 'long': 3, 'fur': 3, 'clouds': 3, 'ears': 3, 'looking': 3, 'wooden': 3, 'chain': 3, 'ear': 3, 'side': 3, 'orange': 2, 'bear': 2, 'water': 2, 'gray': 2, 'hand': 2, 'hat': 2, 'trunk': 2, 'sky': 2, 'standing': 2, 'table': 2, 'head': 2, 'rock': 2, 'around': 2, 'trash': 2, 'feet': 2, 'ground': 2, 'face': 2, 'photo': 2, 'right': 2, 'stuffed': 1, 'teddy': 1, 'baby': 1, 'book': 1, 'body': 1, 'four': 1, 'luggage': 1, 'suitcase': 1, 'woman': 1, 'plastic': 1, 'tall': 1, 'background': 1, 'leaves': 1, 'branches': 1, 'picture': 1, 'young': 1, 'mouth': 1, 'playing': 1, 'outside': 1, 'toilet': 1, 'fence': 1, 'dirt': 1, 'short': 1, 'sidewalk': 1, 'patch': 1, 'behind': 1, 'left': 1}), 'bee': Counter({'small': 20, 'wing': 19, 'leg': 16, 'colored': 12, 'apple': 11, 'pink': 6, 'eating': 5, 'jacket': 5, 'next': 4, 'cake': 4, 'table': 4, 'stuffed': 3, 'wood': 3, 'picture': 3, 'people': 3, 'flowers': 3, 'letters': 3, 'board': 3, 'truck': 3, 'side': 3, 'head': 3, 'floor': 3, 'hair': 2, 'paper': 2, 'near': 2, 'window': 2, 'walking': 2, 'painted': 2, 'shelf': 2, 'dog': 2, 'bear': 2, 'sitting': 2, 'tail': 2, 'sleeve': 2, 'patch': 2, 'orange': 2, 'flower': 2, 'trees': 2, 'color': 2, 'striped': 1, 'grass': 1, 'backpack': 1, 'jeans': 1, 'shorts': 1, 'tile': 1, 'animal': 1, 'kite': 1, 'three': 1, 'stripe': 1, 'guy': 1, 'outside': 1, 'made': 1, 'around': 1, 'flying': 1, 'spoon': 1, 'woman': 1, 'parked': 1, 'sidewalk': 1, 'wheel': 1, 'wheels': 1, 'food': 1, 'glass': 1, 'closed': 1, 'feet': 1, 'back': 1, 'boy': 1, 'bottom': 1, 'plastic': 1, 'teddy': 1, 'design': 1, 'cloth': 1, 'wire': 1, 'long': 1, 'bowl': 1, 'area': 1, 'plant': 1, 'bus': 1, 'stripes': 1, 'branch': 1, 'attached': 1, 'ground': 1, 'vehicle': 1, 'behind': 1, 'elephant': 1, 'watching': 1, 'game': 1, 'frisbee': 1, 'laying': 1, 'counter': 1, 'young': 1, 'edge': 1, 'front': 1}), 'beetle': Counter({'car': 26, 'gray': 18, 'parked': 15, 'street': 8, 'open': 7, 'side': 6, 'building': 5, 'front': 5, 'sidewalk': 4, 'brick': 4, 'truck': 4, 'sign': 4, 'tire': 4, 'lot': 4, 'trunk': 4, 'rack': 4, 'window': 3, 'silver': 3, 'orange': 3, 'stop': 3, 'behind': 3, 'dog': 3, 'bus': 3, 'parking': 3, 'grass': 3, 'cake': 3, 'round': 2, 'road': 2, 'house': 2, 'attached': 2, 'tower': 2, 'cat': 2, 'grey': 2, 'luggage': 2, 'vehicle': 1, 'small': 1, 'gold': 1, 'lettering': 1, 'roof': 1, 'line': 1, 'lamp': 1, 'purple': 1, 'closed': 1, 'fence': 1, 'covered': 1, 'old': 1, 'next': 1, 'back': 1, 'near': 1, 'traffic': 1, 'hydrant': 1, 'blonde': 1, 'scene': 1, 'camera': 1, 'sitting': 1, 'legs': 1, 'background': 1, 'tennis': 1, 'short': 1, 'four': 1, 'people': 1, 'bright': 1, 'airplane': 1, 'surfboard': 1, 'inside': 1, 'van': 1, 'wheel': 1, 'riding': 1, 'bunch': 1, 'clear': 1, 'little': 1, 'statue': 1, 'cars': 1, 'motorcycle': 1, 'handle': 1, 'box': 1, 'letter': 1, 'person': 1, 'windows': 1, 'many': 1, 'flag': 1, 'air': 1, 'plane': 1, 'beige': 1, 'tall': 1}), 'butterfly': Counter({'kite': 147, 'flower': 128, 'orange': 120, 'pink': 92, 'girl': 54, 'bench': 52, 'window': 47, 'sitting': 41, 'wing': 37, 'sky': 34, 'slice': 33, 'side': 29, 'young': 26, 'purple': 23, 'design': 23, 'head': 22, 'small': 21, 'woman': 21, 'picture': 20, 'cake': 20, 'plate': 19, 'bottle': 19, 'gold': 18, 'grey': 18, 'bed': 17, 'flying': 16, 'leaves': 15, 'long': 15, 'fruit': 15, 'vase': 15, 'colorful': 14, 'right': 14, 'wooden': 14, 'legs': 14, 'umbrella': 14, 'table': 13, 'colored': 13, 'cat': 13, 'metal': 13, 'leg': 12, 'little': 12, 'air': 12, 'hanging': 12, 'holding': 12, 'behind': 11, 'cup': 11, 'standing': 11, 'front': 11, 'sign': 11, 'bowl': 11, 'flowers': 10, 'leaf': 10, 'hair': 10, 'bag': 10, 'dark': 9, 'plant': 9, 'left': 9, 'eye': 9, 'pillow': 9, ' ...
# aquarium_fish 7 ['water', 'ocean', 'waves', 'container', 'bowl', 'glass', 'tank']
# beaver 5 ['animal', 'tail', 'water', 'wet', 'wooden']
# bee 2 ['wing', 'flowers']
# beetle 3 ['legs', 'ground', 'dirt']
# camel 5 ['animal', 'horse', 'cow', 'zebra', 'giraffes']
# palm_tree 4 ['trees', 'tree', 'branches', 'leaves']
# shark 4 ['ocean', 'water', 'waves', 'tail']

# %% [markdown]
# # STAGE 6: THE (1+$\lambda$) EVOLUTION STRATEGY IN DETAIL
#
# Welcome to the core of our solution: the **(1+$\lambda$) Evolution Strategy (ES)**. This powerful, yet conceptually simple, Genetic Algorithm will "evolve" a new embedding vector for each of our target words. Think of it as a guided search through the high-dimensional embedding space, aiming to find the perfect location for a new word.
#
# ---
#
# ### 🧬 Evolutionary Algorithms: A Quick Primer
#
# Evolutionary Algorithms (EAs) are a family of optimization techniques inspired by natural evolution. They operate on a *population* of candidate solutions, which iteratively "evolve" over *generations* through processes like:
#
# * **Initialization:** Creating the first set of candidate solutions.
# * **Selection:** Choosing which solutions get to "reproduce" or survive.
# * **Mutation:** Introducing random changes to create new solutions.
# * **Crossover (Recombination):** Combining parts of parent solutions (not used in (1+$\lambda$) ES).
# * **Fitness Evaluation:** Assigning a "quality score" to each solution.
#
# ### The (1+$\lambda$) ES: Parent-Centric Evolution
#
# The (1+$\lambda$) ES is a specific type of EA, where:
#
# * **1:** Represents the single **parent** solution. This is the best solution found so far.
# * **$\lambda$:** Represents the number of **offspring** generated from the parent in each generation.
#
# The process is straightforward:
#
# 1.  **Start with a Parent:** Begin with an initial candidate solution (our embedding vector).
# 2.  **Generate Offspring:** Create $\lambda$ new candidate solutions by adding random "noise" (mutation) to the parent.
# 3.  **Evaluate All:** Calculate the *fitness* of the parent and all $\lambda$ offspring.
# 4.  **Select New Parent:** The best solution (parent or any of the offspring) becomes the parent for the next generation. This ensures that the population always improves or stays the same.
#
# ---
#
# ### 🎯 Our Application: Evolving Word Embeddings
#
# For our task, each "solution" is a `D`-dimensional embedding vector for a target word.
#
# #### 1. Initialization: Bootstrapping from Contexts
#
# How do we start a new word's journey in the embedding space? We give it a head start! The `initialize_embedding` function performs a **corpus bootstrap**:
#
# * It finds the most frequent context words for our target word (e.g., for 'wolf', its contexts might be 'animal', 'forest', 'howl').
# * It then calculates a **weighted average** of the *existing* embedding vectors of these context words.
#
# This creates an initial vector that is already close to where it "should" be, based on its linguistic usage. If no contexts are found, it initializes to the mean of all existing embeddings.

# %%
# =============================================================================
# STAGE 6: RUN THE GENETIC ALGORITHM
# =============================================================================

print("\n[STAGE 6] Evolving New Embeddings via (1+λ) ES")
print("-" * 70)
print(f"Running (1 + {ga_pop_size}) Evolution Strategy for {len(missing_cifar_words)} words...")
print(f"Generations per word: {ga_generations}")

inserted_embeddings_list = []
ga_config = {
    "ga_pop_size": ga_pop_size,
    "ga_generations": ga_generations,
    "ga_mutation_factor": ga_mutation_factor,
    "fitness_weights": fitness_weights
}

# --- Main Evolution Loop ---
for word in missing_cifar_words:
    # Evolve the embedding for this single word
    evolved_vec = evolve_embedding(
        word,
        contexts,
        embeddings,       # The original embedding matrix
        word_to_idx,
        nodes,            # The original vocab list (for neg. sampling)
        embedding_stats,  # Stats for the 'norm' fitness term
        anchors,          # Dict of anchors for the 'anchor' fitness term
        ga_config,         # All GA hyperparameters
        idf = idf,
        idf_threshold = 1.8,
        idf_power = 1.0,
        num_negatives = 15

    )
    inserted_embeddings_list.append(evolved_vec)

# --- Collect Results ---
# We now have a list of new vectors. We stack them into a NumPy
# matrix for easy analysis.
inserted_embeddings = np.array(inserted_embeddings_list)

print(f"\n{'-'*70}")
print(f"✓ STAGE 6 Complete: Evolved {len(missing_cifar_words)} new embeddings.")
# Out:
# [STAGE 6] Evolving New Embeddings via (1+λ) ES
# ----------------------------------------------------------------------
# Running (1 + 100) Evolution Strategy for 68 words...
# Generations per word: 300
#
#   Evolving: 'aquarium_fish' G0=0.5988 G50=0.6083 G100=0.6086 G150=0.6086 G200=0.6086 G250=0.6086 ✓ Final=0.6087
#
#   Evolving: 'beaver' G0=0.6151 G50=0.6181 G100=0.6183 G150=0.6184 G200=0.6184 G250=0.6184 ✓ Final=0.6184
#
#   Evolving: 'bee' G0=0.6164 G50=0.6208 G100=0.6210 G150=0.6211 G200=0.6211 G250=0.6211 ✓ Final=0.6211
#
#   Evolving: 'beetle' G0=0.6246 G50=0.6342 G100=0.6346 G150=0.6347 G200=0.6347 G250=0.6347 ✓ Final=0.6347
#
#   Evolving: 'butterfly' G0=0.6128 G50=0.6152 G100=0.6152 G150=0.6153 G200=0.6153 G250=0.6153 ✓ Final=0.6154
#
#   Evolving: 'camel' G0=0.6287 G50=0.6404 G100=0.6408 G150=0.6408 G200=0.6408 G250=0.6408 ✓ Final=0.6409
#
#   Evolving: 'castle' G0=0.6325 G50=0.6348 G100=0.6350 G150=0.6350 G200=0.6350 G250=0.6351 ✓ Final=0.6351
#
#   Evolving: 'caterpillar' G0=0.6313 G50=0.6371 G100=0.6373 G150=0.6373 G200=0.6374 G250=0.6374 ✓ Final=0.6374
#
#   Evolving: 'cattle' G0=0.6309 G50=0.6333 G100=0.6334 G150=0.6335 G200=0.6335 G250=0.6335 ✓ Final=0.6335
#
#   Evolving: 'chimpanzee' G0=0.6160 G50=0.6205 G100=0.6207 G150=0.6208 G200=0.6208 G250=0.6208 ✓ Final=0.6209
#
#   Evolving: 'cockroach' G0=0.6102 G50=0.6179 G100=0.6181 G150=0.6182 G200=0.6182 G250=0.6183 ✓ Final=0.6183
#
#   Evolving: 'crab' G0=0.6212 G50=0.6334 G100=0.6337 G150=0.6338 G200=0.6338 G250=0.6339 ✓ Final=0.6339
#
#   Evolving: 'crocodile' G0=0.6208 G50=0.6233 G100=0.6235 G150=0.6235 G200=0.6235 G250=0.6236 ✓ Final=0.6236
#
#   Evolving: 'dinosaur' G0=0.6235 G50=0.6311 G100=0.6313 G150=0.6313 G200=0.6314 G250=0.6314 ✓ Final=0.6314
#
#   Evolving: 'dolphin' G0=0.6293 G50=0.6394 G100=0.6398 G150=0.6399 G200=0.6399 G250=0.6399 ✓ Final=0.6399
#
#   Evolving: 'flatfish' G0=0.6054 G50=0.6055 G100=0.6055 G150=0.6055 G200=0.6055 G250=0.6055 ✓ Final=0.6055
#
#   Evolving: 'forest' G0=0.6372 G50=0.6396 G100=0.6397 G150=0.6398 G200=0.6398 G250=0.6398 ✓ Final=0.6398
#
#   Evolving: 'fox' G0=0.6252 G50=0.6308 G100=0.6311 G150=0.6311 G200=0.6312 G250=0.6312 ✓ Final=0.6312
#
#   Evolving: 'hamster' G0=0.6254 G50=0.6290 G100=0.6292 G150=0.6292 G200=0.6293 G250=0.6293 ✓ Final=0.6293
#
#   Evolving: 'kangaroo' G0=0.6208 G50=0.6237 G100=0.6238 G150=0.6239 G200=0.6239 G250=0.6239 ✓ Final=0.6239
#
#   Evolving: 'lawn_mower' G0=0.6160 G50=0.6191 G100=0.6192 G150=0.6192 G200=0.6192 G250=0.6192 ✓ Final=0.6192
#
#   Evolving: 'leopard' G0=0.6230 G50=0.6267 G100=0.6270 G150=0.6270 G200=0.6270 G250=0.6270 ✓ Final=0.6270
#
#   Evolving: 'lion' G0=0.6236 G50=0.6264 G100=0.6265 G150=0.6265 G200=0.6265 G250=0.6266 ✓ Final=0.6266
#
#   Evolving: 'lizard' G0=0.6239 G50=0.6293 G100=0.6294 G150=0.6295 G200=0.6295 G250=0.6295 ✓ Final=0.6296
#
#   Evolving: 'lobster' G0=0.6214 G50=0.6239 G100=0.6240 G150=0.6240 G200=0.6241 G250=0.6241 ✓ Final=0.6241
#
#   Evolving: 'maple_tree' G0=0.6238 G50=0.6286 G100=0.6287 G150=0.6288 G200=0.6288 G250=0.6288 ✓ Final=0.6289
#
#   Evolving: 'mushroom' G0=0.6059 G50=0.6299 G100=0.6316 G150=0.6318 G200=0.6318 G250=0.6318 ✓ Final=0.6318
#
#   Evolving: 'oak_tree' G0=0.6349 G50=0.6387 G100=0.6389 G150=0.6389 G200=0.6389 G250=0.6390 ✓ Final=0.6390
#
#   Evolving: 'orchid' G0=0.6258 G50=0.6274 G100=0.6275 G150=0.6276 G200=0.6276 G250=0.6276 ✓ Final=0.6276
#
#   Evolving: 'otter' G0=0.6159 G50=0.6193 G100=0.6195 G150=0.6195 G200=0.6195 G250=0.6196 ✓ Final=0.6196
#
#   Evolving: 'palm_tree' G0=0.6393 G50=0.6430 G100=0.6432 G150=0.6433 G200=0.6433 G250=0.6433 ✓ Final=0.6433
#
#   Evolving: 'pear' G0=0.6319 G50=0.6343 G100=0.6344 G150=0.6346 G200=0.6346 G250=0.6346 ✓ Final=0.6346
#
#   Evolving: 'pickup_truck' G0=0.6266 G50=0.6301 G100=0.6302 G150=0.6302 G200=0.6302 G250=0.6303 ✓ Final=0.6303
#
#   Evolving: 'pine_tree' G0=0.6352 G50=0.6386 G100=0.6388 G150=0.6389 G200=0.6389 G250=0.6389 ✓ Final=0.6389
#
#   Evolving: 'plain' G0=0.6256 G50=0.6330 G100=0.6331 G150=0.6332 G200=0.6332 G250=0.6332 ✓ Final=0.6332
#
#   Evolving: 'poppy' G0=0.6111 G50=0.6229 G100=0.6234 G150=0.6235 G200=0.6235 G250=0.6235 ✓ Final=0.6236
#
#   Evolving: 'porcupine' G0=0.6117 G50=0.6173 G100=0.6175 G150=0.6176 G200=0.6176 G250=0.6176 ✓ Final=0.6176
#
#   Evolving: 'possum' G0=0.6060 G50=0.6062 G100=0.6062 G150=0.6062 G200=0.6063 G250=0.6063 ✓ Final=0.6063
#
#   Evolving: 'rabbit' G0=0.6271 G50=0.6324 G100=0.6326 G150=0.6327 G200=0.6327 G250=0.6327 ✓ Final=0.6328
#
#   Evolving: 'raccoon' G0=0.6159 G50=0.6229 G100=0.6230 G150=0.6230 G200=0.6230 G250=0.6231 ✓ Final=0.6232
#
#   Evolving: 'ray' G0=0.6204 G50=0.6237 G100=0.6238 G150=0.6238 G200=0.6238 G250=0.6238 ✓ Final=0.6238
#
#   Evolving: 'rocket' G0=0.6243 G50=0.6263 G100=0.6264 G150=0.6265 G200=0.6265 G250=0.6265 ✓ Final=0.6265
#
#   Evolving: 'rose' G0=0.6297 G50=0.6304 G100=0.6304 G150=0.6305 G200=0.6305 G250=0.6305 ✓ Final=0.6305
#
#   Evolving: 'sea' G0=0.6363 G50=0.6380 G100=0.6381 G150=0.6382 G200=0.6383 G250=0.6383 ✓ Final=0.6383
#
#   Evolving: 'seal' G0=0.6257 G50=0.6363 G100=0.6368 G150=0.6369 G200=0.6369 G250=0.6370 ✓ Final=0.6370
#
#   Evolving: 'shark' G0=0.6253 G50=0.6300 G100=0.6302 G150=0.6302 G200=0.6302 G250=0.6302 ✓ Final=0.6303
#
#   Evolving: 'shrew' G0=0.6080 G50=0.6081 G100=0.6083 G150=0.6083 G200=0.6083 G250=0.6083 ✓ Final=0.6083
#
#   Evolving: 'skunk' G0=0.6111 G50=0.6162 G100=0.6165 G150=0.6166 G200=0.6166 G250=0.6166 ✓ Final=0.6167
#
#   Evolving: 'skyscraper' G0=0.6323 G50=0.6344 G100=0.6347 G150=0.6347 G200=0.6348 G250=0.6348 ✓ Final=0.6348
#
#   Evolving: 'snail' G0=0.6145 G50=0.6265 G100=0.6270 G150=0.6270 G200=0.6270 G250=0.6271 ✓ Final=0.6271
#
#   Evolving: 'snake' G0=0.6257 G50=0.6304 G100=0.6306 G150=0.6306 G200=0.6306 G250=0.6306 ✓ Final=0.6306
#
#   Evolving: 'spider' G0=0.6243 G50=0.6335 G100=0.6337 G150=0.6338 G200=0.6338 G250=0.6338 ✓ Final=0.6339
#
#   Evolving: 'squirrel' G0=0.6233 G50=0.6285 G100=0.6287 G150=0.6288 G200=0.6289 G250=0.6289 ✓ Final=0.6289
#
#   Evolving: 'streetcar' G0=0.6294 G50=0.6322 G100=0.6324 G150=0.6325 G200=0.6325 G250=0.6326 ✓ Final=0.6326
#
#   Evolving: 'sunflower' G0=0.6183 G50=0.6234 G100=0.6236 G150=0.6236 G200=0.6237 G250=0.6237 ✓ Final=0.6237
#
#   Evolving: 'sweet_pepper' G0=0.6237 G50=0.6256 G100=0.6257 G150=0.6257 G200=0.6258 G250=0.6258 ✓ Final=0.6258
#
#   Evolving: 'telephone' G0=0.6246 G50=0.6374 G100=0.6377 G150=0.6378 G200=0.6379 G250=0.6379 ✓ Final=0.6379
#
#   Evolving: 'television' G0=0.6360 G50=0.6410 G100=0.6412 G150=0.6412 G200=0.6413 G250=0.6413 ✓ Final=0.6413
#
#   Evolving: 'tiger' G0=0.6231 G50=0.6253 G100=0.6255 G150=0.6256 G200=0.6256 G250=0.6256 ✓ Final=0.6256
#
#   Evolving: 'tractor' G0=0.6252 G50=0.6267 G100=0.6268 G150=0.6269 G200=0.6269 G250=0.6269 ✓ Final=0.6269
#
#   Evolving: 'trout' G0=0.6092 G50=0.6178 G100=0.6181 G150=0.6182 G200=0.6183 G250=0.6183 ✓ Final=0.6183
#
#   Evolving: 'tulip' G0=0.6286 G50=0.6292 G100=0.6294 G150=0.6294 G200=0.6294 G250=0.6294 ✓ Final=0.6294
#
#   Evolving: 'turtle' G0=0.6246 G50=0.6320 G100=0.6324 G150=0.6325 G200=0.6325 G250=0.6325 ✓ Final=0.6325
#
#   Evolving: 'wardrobe' G0=0.6201 G50=0.6350 G100=0.6357 G150=0.6357 G200=0.6358 G250=0.6358 ✓ Final=0.6358
#
#   Evolving: 'whale' G0=0.6293 G50=0.6359 G100=0.6363 G150=0.6363 G200=0.6363 G250=0.6363 ✓ Final=0.6364
#
#   Evolving: 'willow_tree' G0=0.6311 G50=0.6341 G100=0.6342 G150=0.6343 G200=0.6343 G250=0.6344 ✓ Final=0.6344
#
#   Evolving: 'wolf' G0=0.6264 G50=0.6292 G100=0.6293 G150=0.6293 G200=0.6294 G250=0.6294 ✓ Final=0.6294
#
#   Evolving: 'worm' G0=0.6246 G50=0.6330 G100=0.6334 G150=0.6334 G200=0.6335 G250=0.6335 ✓ Final=0.6335
#
# ----------------------------------------------------------------------
# ✓ STAGE 6 Complete: Evolved 68 new embeddings.

# %%
# =============================================================================
# STAGE 7: MERGE EMBEDDINGS
# =============================================================================
# We now have two sets of embeddings:
# 1. `embeddings`: The original (N x D) matrix for the original `nodes`.
# 2. `inserted_embeddings`: Our new (K x D) matrix for the `target_words`.
#
# To analyze and visualize them together, we simply stack them into
# one large matrix and one large vocabulary list.

print("\n[STAGE 7] Combining Original and Evolved Embeddings")
print("-" * 70)

# `np.vstack` stacks the two matrices vertically, creating a
# new matrix of shape (N + K, D).
all_embeddings = np.vstack([embeddings, inserted_embeddings])

# We concatenate the vocabulary lists in the *same order*.
# - Indices 0 to N-1 correspond to the original `nodes`.
# - Indices N to N+K-1 correspond to our new `target_words`.
all_vocab = nodes + missing_cifar_words

print(f"✓ Combined embedding matrix shape: {all_embeddings.shape}")
print(f"✓ Combined vocabulary size: {len(all_vocab)} words")
print(f"  ├─ Original words: {len(nodes)}")
print(f"  └─ Newly inserted words: {len(missing_cifar_words)}")
# Out:
# [STAGE 7] Combining Original and Evolved Embeddings
# ----------------------------------------------------------------------
# ✓ Combined embedding matrix shape: (523, 96)
# ✓ Combined vocabulary size: 523 words
#   ├─ Original words: 455
#   └─ Newly inserted words: 68

# %%
# =============================================================================
# STAGE 8: ANALYSIS & VERIFICATION
# =============================================================================
# This is the moment of truth!
#
# We will use the `analyze_embeddings` function from Lab 6 to run a
# standard set of quality checks on our *newly combined* embedding space.
#
# We will specifically test our newly inserted words to see if they
# behave logically.
#
# 1. Similarity: We'll find the nearest neighbors for our new words.
#    (e.g., are 'dog' and 'animal' near 'wolf'?).
# 2. Analogies: We'll dynamically create analogies using our anchor list.
#    (e.g., "dog is to cat as wolf is to ???")
# 3. Clustering: We'll use our new words as seeds for clustering.

print("\n[STAGE 8] Analyzing Combined Embedding Space")
print("-" * 70)

# --- 1. Setup Similarity Test ---
# We'll just use the first few target words as examples.
similarity_examples = missing_cifar_words[:]
print(f"Running similarity checks for: {similarity_examples}")

# --- 2. Setup Analogy Test ---
# Let's auto-create analogy tasks based on our anchor list.
# e.g., if anchors['wolf'] = ['dog', 'animal', ...],
# we create the analogy ('dog', 'animal', 'wolf').
# The model should solve: "dog" - "animal" + "wolf" approx ???
analogy_examples = []
for word in missing_cifar_words:
    if word in anchors and len(anchors[word]) >= 2:
        # Create an analogy: (anchor1, anchor2, new_word)
        analogy_examples.append((
            anchors[word][0],  # e.g., 'dog'
            anchors[word][1],  # e.g., 'animal'
            word               # e.g., 'wolf'
        ))
    if len(analogy_examples) >= 3:
        break  # Limit to 3 analogies for brevity
print(f"Running analogy checks for: {analogy_examples}")

# --- 3. Setup Clustering Test ---
# We'll use our newly inserted words as the seeds for clustering.
# This helps us see which original words group around our new ones.
cluster_seeds = missing_cifar_words
print(f"Running clustering checks for: {cluster_seeds}")

# --- 4. Run Full Analysis ---
analyze_embeddings(
    nodes=all_vocab,  # <--- FIX: Renamed 'vocabulary' to 'nodes'
    embeddings=all_embeddings,
    similarity_examples=similarity_examples,
    analogy_examples=analogy_examples,
    cluster_seeds=cluster_seeds
)
# Out:
# [STAGE 8] Analyzing Combined Embedding Space
# ----------------------------------------------------------------------
# Running similarity checks for: ['aquarium_fish', 'beaver', 'bee', 'beetle', 'butterfly', 'camel', 'castle', 'caterpillar', 'cattle', 'chimpanzee', 'cockroach', 'crab', 'crocodile', 'dinosaur', 'dolphin', 'flatfish', 'forest', 'fox', 'hamster', 'kangaroo', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'maple_tree', 'mushroom', 'oak_tree', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'telephone', 'television', 'tiger', 'tractor', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'worm']
# Running analogy checks for: [('water', 'ocean', 'aquarium_fish'), ('animal', 'tail', 'beaver'), ('wing', 'flowers', 'bee')]
# Running clustering checks for: ['aquarium_fish', 'beaver', 'bee', 'beetle', 'butterfly', 'camel', 'castle', 'caterpillar', 'cattle', 'chimpanzee', 'cockroach', 'crab', 'crocodile', 'dinosaur', 'dolphin', 'flatfish', 'forest', 'fox', 'hamster', 'kangaroo', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'maple_tree', 'mushroom', 'oak_tree', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'telephone', 'television', 'tiger', 'tractor', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'worm']
#
# ================================================================================
# EMBEDDING ANALYSIS
# ================================================================================
#
# Vocabulary: 523  Embedding dim: 96
#
# Similarity stats (100 word sample):
#   Mean: 0.5443  Std: 0.1546
#   Min: 0.2027  Max: 0.9802
#
# ================================================================================
# NEAREST NEIGHBORS
# ================================================================================
#
# Most similar to 'aquarium_fish':
#   trout            similarity=0.9354
#   water            similarity=0.9291
#   bottle           similarity=0.8877
#   lobster          similarity=0.8835
#   boat             similarity=0.8725
#   dolphin          similarity=0.8696
#   sea              similarity=0.8696
#   shark            similarity=0.8685
#
# Most similar to 'beaver':
#   otter            similarity=0.9319
#   crocodile        similarity=0.9306
#   flatfish         similarity=0.9294
#   snake            similarity=0.9294
#   lizard           similarity=0.9192
#   raccoon          similarity=0.9176
#   dinosaur         similarity=0.9172
#   mushroom         similarity=0.9163
#
# Most similar to 'bee':
#   butterfly        similarity=0.9490
#   rocket           similarity=0.8647
#   sunflower        similarity=0.8630
#   ray              similarity=0.8489
#   lawn_mower       similarity=0.8341
#   boat             similarity=0.8331
#   wing             similarity=0.8313
#   line             similarity=0.8312
#
# Most similar to 'beetle':
#   spider           similarity=0.9644
#   skunk            similarity=0.9637
#   shrew            similarity=0.9555
#   cockroach        similarity=0.9523
#   lizard           similarity=0.9465
#   kangaroo         similarity=0.9460
#   ground           similarity=0.9453
#   mushroom         similarity=0.9424
#
# Most similar to 'butterfly':
#   bee              similarity=0.9490
#   sunflower        similarity=0.9412
#   design           similarity=0.9104
#   tulip            similarity=0.9048
#   poppy            similarity=0.9037
#   rose             similarity=0.8926
#   ray              similarity=0.8877
#   orchid           similarity=0.8807
#
# Most similar to 'camel':
#   cow              similarity=0.9815
#   zebra            similarity=0.9661
#   giraffe          similarity=0.9652
#   sheep            similarity=0.9649
#   cattle           similarity=0.9536
#   horse            similarity=0.9532
#   elephant         similarity=0.9508
#   cows             similarity=0.9462
#
# Most similar to 'castle':
#   skyscraper       similarity=0.9634
#   building         similarity=0.9633
#   bridge           similarity=0.9225
#   roof             similarity=0.9175
#   tower            similarity=0.9088
#   house            similarity=0.9088
#   window           similarity=0.8915
#   buildings        similarity=0.8875
#
# Most similar to 'caterpillar':
#   maple_tree       similarity=0.9593
#   leaves           similarity=0.9560
#   palm_tree        similarity=0.9530
#   leaf             similarity=0.9509
#   plant            similarity=0.9440
#   oak_tree         similarity=0.9420
#   tree             similarity=0.9392
#   bush             similarity=0.9375
#
# Most similar to 'cattle':
#   camel            similarity=0.9536
#   cow              similarity=0.9389
#   shrew            similarity=0.9319
#   skunk            similarity=0.9300
#   porcupine        similarity=0.9296
#   horse            similarity=0.9266
#   hamster          similarity=0.9207
#   elephant         similarity=0.9175
#
# Most similar to 'chimpanzee':
#   face             similarity=0.9414
#   head             similarity=0.9392
#   lion             similarity=0.9378
#   dinosaur         similarity=0.9285
#   raccoon          similarity=0.9277
#   crocodile        similarity=0.9241
#   feet             similarity=0.9236
#   lizard           similarity=0.9195
#
# Most similar to 'cockroach':
#   beetle           similarity=0.9523
#   mushroom         similarity=0.9299
#   worm             similarity=0.9256
#   skunk            similarity=0.9155
#   beaver           similarity=0.9147
#   spider           similarity=0.9145
#   ground           similarity=0.9139
#   area             similarity=0.9131
#
# Most similar to 'crab':
#   turtle           similarity=0.9787
#   seal             similarity=0.9689
#   sand             similarity=0.9639
#   otter            similarity=0.9501
#   trout            similarity=0.9414
#   beach            similarity=0.9403
#   flatfish         similarity=0.9401
#   water            similarity=0.9396
#
# Most similar to 'crocodile':
#   dinosaur         similarity=0.9799
#   lizard           similarity=0.9790
#   raccoon          similarity=0.9743
#   kangaroo         similarity=0.9688
#   rabbit           similarity=0.9680
#   snake            similarity=0.9656
#   hamster          similarity=0.9634
#   lion             similarity=0.9607
#
# Most similar to 'dinosaur':
#   lizard           similarity=0.9867
#   snake            similarity=0.9813
#   crocodile        similarity=0.9799
#   lion             similarity=0.9739
#   raccoon          similarity=0.9691
#   kangaroo         similarity=0.9666
#   rabbit           similarity=0.9632
#   leopard          similarity=0.9538
#
# Most similar to 'dolphin':
#   ocean            similarity=0.9689
#   sea              similarity=0.9683
#   whale            similarity=0.9615
#   shark            similarity=0.9577
#   waves            similarity=0.9567
#   trout            similarity=0.9525
#   wave             similarity=0.9412
#   water            similarity=0.9349
#
# Most similar to 'flatfish':
#   ray              similarity=0.9468
#   crab             similarity=0.9401
#   beaver           similarity=0.9294
#   seal             similarity=0.9286
#   otter            similarity=0.9275
#   turtle           similarity=0.9254
#   water            similarity=0.9219
#   sand             similarity=0.9104
#
# Most similar to 'forest':
#   oak_tree         similarity=0.9874
#   willow_tree      similarity=0.9807
#   palm_tree        similarity=0.9796
#   maple_tree       similarity=0.9772
#   pine_tree        similarity=0.9729
#   worm             similarity=0.9634
#   squirrel         similarity=0.9530
#   skunk            similarity=0.9526
#
# Most similar to 'fox':
#   wolf             similarity=0.9764
#   rabbit           similarity=0.9642
#   leopard          similarity=0.9530
#   hamster          similarity=0.9473
#   tiger            similarity=0.9470
#   raccoon          similarity=0.9453
#   crocodile        similarity=0.9411
#   lion             similarity=0.9339
#
# Most similar to 'hamster':
#   rabbit           similarity=0.9725
#   lizard           similarity=0.9652
#   crocodile        similarity=0.9634
#   kangaroo         similarity=0.9631
#   raccoon          similarity=0.9627
#   wolf             similarity=0.9626
#   shrew            similarity=0.9593
#   possum           similarity=0.9565
#
# Most similar to 'kangaroo':
#   lizard           similarity=0.9819
#   raccoon          similarity=0.9707
#   crocodile        similarity=0.9688
#   dinosaur         similarity=0.9666
#   snake            similarity=0.9651
#   hamster          similarity=0.9631
#   possum           similarity=0.9606
#   rabbit           similarity=0.9543
#
# Most similar to 'lawn_mower':
#   tractor          similarity=0.9712
#   skunk            similarity=0.9139
#   beetle           similarity=0.9114
#   worm             similarity=0.9090
#   cockroach        similarity=0.9083
#   ground           similarity=0.9029
#   road             similarity=0.9018
#   mushroom         similarity=0.8993
#
# Most similar to 'leopard':
#   tiger            similarity=0.9733
#   wolf             similarity=0.9670
#   lion             similarity=0.9655
#   rabbit           similarity=0.9592
#   lizard           similarity=0.9564
#   crocodile        similarity=0.9551
#   dinosaur         similarity=0.9538
#   fox              similarity=0.9530
#
# Most similar to 'lion':
#   dinosaur         similarity=0.9739
#   lizard           similarity=0.9678
#   tiger            similarity=0.9659
#   leopard          similarity=0.9655
#   crocodile        similarity=0.9607
#   wolf             similarity=0.9579
#   rabbit           similarity=0.9547
#   raccoon          similarity=0.9546
#
# Most similar to 'lizard':
#   dinosaur         similarity=0.9867
#   snake            similarity=0.9845
#   kangaroo         similarity=0.9819
#   crocodile        similarity=0.9790
#   raccoon          similarity=0.9741
#   lion             similarity=0.9678
#   hamster          similarity=0.9652
#   rabbit           similarity=0.9596
#
# Most similar to 'lobster':
#   sweet_pepper     similarity=0.9497
#   cake             similarity=0.9462
#   sandwich         similarity=0.9317
#   dish             similarity=0.9229
#   bread            similarity=0.9209
#   plate            similarity=0.9188
#   pizza            similarity=0.9094
#   food             similarity=0.9076
#
# Most similar to 'maple_tree':
#   oak_tree         similarity=0.9829
#   palm_tree        similarity=0.9808
#   forest           similarity=0.9772
#   willow_tree      similarity=0.9741
#   bush             similarity=0.9644
#   pine_tree        similarity=0.9615
#   tree             similarity=0.9603
#   caterpillar      similarity=0.9593
#
# Most similar to 'mushroom':
#   worm             similarity=0.9827
#   snail            similarity=0.9823
#   skunk            similarity=0.9495
#   dirt             similarity=0.9479
#   poppy            similarity=0.9478
#   forest           similarity=0.9469
#   grass            similarity=0.9443
#   beetle           similarity=0.9424
#
# Most similar to 'oak_tree':
#   palm_tree        similarity=0.9898
#   forest           similarity=0.9874
#   willow_tree      similarity=0.9865
#   maple_tree       similarity=0.9829
#   pine_tree        similarity=0.9782
#   branches         similarity=0.9610
#   tree             similarity=0.9581
#   trees            similarity=0.9548
#
# Most similar to 'orchid':
#   rose             similarity=0.9763
#   tulip            similarity=0.9718
#   design           similarity=0.9366
#   sunflower        similarity=0.9084
#   purple           similarity=0.9071
#   poppy            similarity=0.9004
#   pink             similarity=0.8885
#   colored          similarity=0.8883
#
# Most similar to 'otter':
#   shark            similarity=0.9579
#   crab             similarity=0.9501
#   turtle           similarity=0.9373
#   ray              similarity=0.9363
#   beaver           similarity=0.9319
#   seal             similarity=0.9299
#   flatfish         similarity=0.9275
#   sea              similarity=0.9275
#
# Most similar to 'palm_tree':
#   oak_tree         similarity=0.9898
#   willow_tree      similarity=0.9814
#   maple_tree       similarity=0.9808
#   forest           similarity=0.9796
#   tree             similarity=0.9732
#   pine_tree        similarity=0.9710
#   branches         similarity=0.9675
#   bush             similarity=0.9566
#
# Most similar to 'pear':
#   fruit            similarity=0.9523
#   basket           similarity=0.9275
#   banana           similarity=0.9242
#   container        similarity=0.9121
#   bananas          similarity=0.9119
#   box              similarity=0.9092
#   sweet_pepper     similarity=0.9085
#   napkin           similarity=0.9021
#
# Most similar to 'pickup_truck':
#   streetcar        similarity=0.9107
#   wheels           similarity=0.9080
#   tractor          similarity=0.9045
#   truck            similarity=0.9032
#   windshield       similarity=0.9023
#   vehicle          similarity=0.9003
#   tire             similarity=0.8979
#   car              similarity=0.8947
#
# Most similar to 'pine_tree':
#   willow_tree      similarity=0.9811
#   oak_tree         similarity=0.9782
#   forest           similarity=0.9729
#   palm_tree        similarity=0.9710
#   trees            similarity=0.9665
#   maple_tree       similarity=0.9615
#   squirrel         similarity=0.9468
#   tree             similarity=0.9445
#
# Most similar to 'plain':
#   pine_tree        similarity=0.9347
#   ground           similarity=0.9316
#   willow_tree      similarity=0.9291
#   skunk            similarity=0.9275
#   forest           similarity=0.9215
#   spider           similarity=0.9204
#   squirrel         similarity=0.9175
#   worm             similarity=0.9151
#
# Most similar to 'poppy':
#   sunflower        similarity=0.9687
#   worm             similarity=0.9491
#   mushroom         similarity=0.9478
#   snail            similarity=0.9398
#   tulip            similarity=0.9314
#   forest           similarity=0.9142
#   rose             similarity=0.9134
#   butterfly        similarity=0.9037
#
# Most similar to 'porcupine':
#   skunk            similarity=0.9840
#   possum           similarity=0.9821
#   shrew            similarity=0.9743
#   squirrel         similarity=0.9733
#   kangaroo         similarity=0.9540
#   raccoon          similarity=0.9483
#   spider           similarity=0.9464
#   hamster          similarity=0.9434
#
# Most similar to 'possum':
#   shrew            similarity=0.9869
#   porcupine        similarity=0.9821
#   skunk            similarity=0.9723
#   raccoon          similarity=0.9655
#   squirrel         similarity=0.9626
#   kangaroo         similarity=0.9606
#   hamster          similarity=0.9565
#   spider           similarity=0.9504
#
# Most similar to 'rabbit':
#   hamster          similarity=0.9725
#   crocodile        similarity=0.9680
#   wolf             similarity=0.9666
#   fox              similarity=0.9642
#   dinosaur         similarity=0.9632
#   raccoon          similarity=0.9615
#   lizard           similarity=0.9596
#   leopard          similarity=0.9592
#
# Most similar to 'raccoon':
#   snake            similarity=0.9766
#   crocodile        similarity=0.9743
#   lizard           similarity=0.9741
#   kangaroo         similarity=0.9707
#   dinosaur         similarity=0.9691
#   possum           similarity=0.9655
#   hamster          similarity=0.9627
#   rabbit           similarity=0.9615
#
# Most similar to 'ray':
#   flatfish         similarity=0.9468
#   otter            similarity=0.9363
#   turtle           similarity=0.9238
#   shark            similarity=0.9168
#   crab             similarity=0.9130
#   photo            similarity=0.9051
#   trout            similarity=0.9029
#   sea              similarity=0.9007
#
# Most similar to 'rocket':
#   airplane         similarity=0.9252
#   plane            similarity=0.9216
#   jet              similarity=0.9116
#   engine           similarity=0.8966
#   tractor          similarity=0.8894
#   air              similarity=0.8870
#   sky              similarity=0.8770
#   streetcar        similarity=0.8756
#
# Most similar to 'rose':
#   tulip            similarity=0.9853
#   orchid           similarity=0.9763
#   flowers          similarity=0.9166
#   sunflower        similarity=0.9153
#   poppy            similarity=0.9134
#   design           similarity=0.9064
#   flower           similarity=0.9035
#   plant            similarity=0.8964
#
# Most similar to 'sea':
#   whale            similarity=0.9911
#   shark            similarity=0.9727
#   dolphin          similarity=0.9683
#   ocean            similarity=0.9575
#   trout            similarity=0.9535
#   beach            similarity=0.9482
#   water            similarity=0.9365
#   crab             similarity=0.9298
#
# Most similar to 'seal':
#   sand             similarity=0.9708
#   crab             similarity=0.9689
#   turtle           similarity=0.9407
#   beach            similarity=0.9354
#   otter            similarity=0.9299
#   flatfish         similarity=0.9286
#   shark            similarity=0.9255
#   sea              similarity=0.9151
#
# Most similar to 'shark':
#   sea              similarity=0.9727
#   whale            similarity=0.9679
#   otter            similarity=0.9579
#   dolphin          similarity=0.9577
#   trout            similarity=0.9432
#   water            similarity=0.9406
#   crab             similarity=0.9393
#   ocean            similarity=0.9393
#
# Most similar to 'shrew':
#   possum           similarity=0.9869
#   skunk            similarity=0.9771
#   porcupine        similarity=0.9743
#   hamster          similarity=0.9593
#   raccoon          similarity=0.9564
#   beetle           similarity=0.9555
#   spider           similarity=0.9531
#   kangaroo         similarity=0.9516
#
# Most similar to 'skunk':
#   porcupine        similarity=0.9840
#   shrew            similarity=0.9771
#   possum           similarity=0.9723
#   squirrel         similarity=0.9693
#   beetle           similarity=0.9637
#   spider           similarity=0.9612
#   worm             similarity=0.9559
#   forest           similarity=0.9526
#
# Most similar to 'skyscraper':
#   castle           similarity=0.9634
#   building         similarity=0.9535
#   roof             similarity=0.9175
#   buildings        similarity=0.9146
#   windows          similarity=0.9138
#   streetcar        similarity=0.9108
#   sign             similarity=0.9094
#   city             similarity=0.9055
#
# Most similar to 'snail':
#   mushroom         similarity=0.9823
#   worm             similarity=0.9669
#   poppy            similarity=0.9398
#   grass            similarity=0.9370
#   forest           similarity=0.9344
#   skunk            similarity=0.9340
#   willow_tree      similarity=0.9299
#   maple_tree       similarity=0.9273
#
# Most similar to 'snake':
#   lizard           similarity=0.9845
#   dinosaur         similarity=0.9813
#   raccoon          similarity=0.9766
#   crocodile        similarity=0.9656
#   kangaroo         similarity=0.9651
#   lion             similarity=0.9508
#   leopard          similarity=0.9434
#   possum           similarity=0.9424
#
# Most similar to 'spider':
#   beetle           similarity=0.9644
#   skunk            similarity=0.9612
#   shrew            similarity=0.9531
#   possum           similarity=0.9504
#   porcupine        similarity=0.9464
#   kangaroo         similarity=0.9430
#   ground           similarity=0.9383
#   lizard           similarity=0.9368
#
# Most similar to 'squirrel':
#   porcupine        similarity=0.9733
#   skunk            similarity=0.9693
#   possum           similarity=0.9626
#   forest           similarity=0.9530
#   shrew            similarity=0.9493
#   willow_tree      similarity=0.9490
#   pine_tree        similarity=0.9468
#   oak_tree         similarity=0.9440
#
# Most similar to 'streetcar':
#   train            similarity=0.9517
#   bus              similarity=0.9497
#   car              similarity=0.9379
#   vehicle          similarity=0.9242
#   tractor          similarity=0.9147
#   road             similarity=0.9121
#   skyscraper       similarity=0.9108
#   pickup_truck     similarity=0.9107
#
# Most similar to 'sunflower':
#   poppy            similarity=0.9687
#   butterfly        similarity=0.9412
#   tulip            similarity=0.9213
#   rose             similarity=0.9153
#   large            similarity=0.9122
#   orchid           similarity=0.9084
#   line             similarity=0.9060
#   photo            similarity=0.9053
#
# Most similar to 'sweet_pepper':
#   bread            similarity=0.9720
#   sandwich         similarity=0.9684
#   pizza            similarity=0.9518
#   lobster          similarity=0.9497
#   plate            similarity=0.9398
#   cheese           similarity=0.9382
#   cake             similarity=0.9363
#   dish             similarity=0.9352
#
# Most similar to 'telephone':
#   television       similarity=0.9692
#   keyboard         similarity=0.9582
#   laptop           similarity=0.9564
#   monitor          similarity=0.9486
#   screen           similarity=0.9392
#   computer         similarity=0.9350
#   remote           similarity=0.9217
#   mouse            similarity=0.9215
#
# Most similar to 'television':
#   telephone        similarity=0.9692
#   monitor          similarity=0.9640
#   laptop           similarity=0.9621
#   keyboard         similarity=0.9520
#   computer         similarity=0.9477
#   desk             similarity=0.9468
#   tv               similarity=0.9445
#   screen           similarity=0.9353
#
# Most similar to 'tiger':
#   leopard          similarity=0.9733
#   lion             similarity=0.9659
#   wolf             similarity=0.9588
#   fox              similarity=0.9470
#   rabbit           similarity=0.9459
#   dinosaur         similarity=0.9426
#   lizard           similarity=0.9377
#   crocodile        similarity=0.9326
#
# Most similar to 'tractor':
#   lawn_mower       similarity=0.9712
#   streetcar        similarity=0.9147
#   vehicle          similarity=0.9091
#   pickup_truck     similarity=0.9045
#   wheels           similarity=0.9003
#   beetle           similarity=0.8953
#   skunk            similarity=0.8952
#   truck            similarity=0.8895
#
# Most similar to 'trout':
#   water            similarity=0.9599
#   sea              similarity=0.9535
#   dolphin          similarity=0.9525
#   shark            similarity=0.9432
#   crab             similarity=0.9414
#   whale            similarity=0.9374
#   aquarium_fish    similarity=0.9354
#   beach            similarity=0.9265
#
# Most similar to 'tulip':
#   rose             similarity=0.9853
#   orchid           similarity=0.9718
#   poppy            similarity=0.9314
#   flowers          similarity=0.9241
#   sunflower        similarity=0.9213
#   design           similarity=0.9170
#   flower           similarity=0.9114
#   butterfly        similarity=0.9048
#
# Most similar to 'turtle':
#   crab             similarity=0.9787
#   sand             similarity=0.9408
#   seal             similarity=0.9407
#   otter            similarity=0.9373
#   beach            similarity=0.9329
#   flatfish         similarity=0.9254
#   trout            similarity=0.9243
#   ray              similarity=0.9238
#
# Most similar to 'wardrobe':
#   coat             similarity=0.9592
#   jacket           similarity=0.9585
#   hat              similarity=0.9548
#   sweater          similarity=0.9513
#   pants            similarity=0.9490
#   backpack         similarity=0.9450
#   shorts           similarity=0.9337
#   shoes            similarity=0.9282
#
# Most similar to 'whale':
#   sea              similarity=0.9911
#   shark            similarity=0.9679
#   dolphin          similarity=0.9615
#   ocean            similarity=0.9547
#   trout            similarity=0.9374
#   waves            similarity=0.9273
#   water            similarity=0.9204
#   beach            similarity=0.9145
#
# Most similar to 'willow_tree':
#   oak_tree         similarity=0.9865
#   palm_tree        similarity=0.9814
#   pine_tree        similarity=0.9811
#   forest           similarity=0.9807
#   maple_tree       similarity=0.9741
#   trees            similarity=0.9564
#   squirrel         similarity=0.9490
#   branches         similarity=0.9485
#
# Most similar to 'wolf':
#   fox              similarity=0.9764
#   leopard          similarity=0.9670
#   rabbit           similarity=0.9666
#   hamster          similarity=0.9626
#   tiger            similarity=0.9588
#   lion             similarity=0.9579
#   crocodile        similarity=0.9573
#   lizard           similarity=0.9548
#
# Most similar to 'worm':
#   mushroom         similarity=0.9827
#   snail            similarity=0.9669
#   forest           similarity=0.9634
#   grass            similarity=0.9561
#   skunk            similarity=0.9559
#   poppy            similarity=0.9491
#   maple_tree       similarity=0.9473
#   dirt             similarity=0.9450
#
# ================================================================================
# WORD ANALOGIES (a:b :: c:?)
# ================================================================================
#
# water:ocean :: aquarium_fish:?
#   dolphin          score=0.9384
#   sea              score=0.9267
#   whale            score=0.9216
#
# animal:tail :: beaver:?
#   body             score=0.8439
#   snake            score=0.8269
#   dinosaur         score=0.8212
#
# wing:flowers :: bee:?
#   flower           score=0.8453
#   tulip            score=0.7858
#   rose             score=0.7817
#
# ================================================================================
# SEMANTIC CLUSTERS
# ================================================================================
#
# 'aquarium_fish': trout, water, bottle, lobster, boat
#
# 'beaver': otter, crocodile, flatfish, snake, lizard
#
# 'bee': butterfly, rocket, sunflower, ray, lawn_mower
#
# 'beetle': spider, skunk, shrew, cockroach, lizard
#
# 'butterfly': bee, sunflower, design, tulip, poppy
#
# 'camel': cow, zebra, giraffe, sheep, cattle
#
# 'castle': skyscraper, building, bridge, roof, tower
#
# 'caterpillar': maple_tree, leaves, palm_tree, leaf, plant
#
# 'cattle': camel, cow, shrew, skunk, porcupine
#
# 'chimpanzee': face, head, lion, dinosaur, raccoon
#
# 'cockroach': beetle, mushroom, worm, skunk, beaver
#
# 'crab': turtle, seal, sand, otter, trout
#
# 'crocodile': dinosaur, lizard, raccoon, kangaroo, rabbit
#
# 'dinosaur': lizard, snake, crocodile, lion, raccoon
#
# 'dolphin': ocean, sea, whale, shark, waves
#
# 'flatfish': ray, crab, beaver, seal, otter
#
# 'forest': oak_tree, willow_tree, palm_tree, maple_tree, pine_tree
#
# 'fox': wolf, rabbit, leopard, hamster, tiger
#
# 'hamster': rabbit, lizard, crocodile, kangaroo, raccoon
#
# 'kangaroo': lizard, raccoon, crocodile, dinosaur, snake
#
# 'lawn_mower': tractor, skunk, beetle, worm, cockroach
#
# 'leopard': tiger, wolf, lion, rabbit, lizard
#
# 'lion': dinosaur, lizard, tiger, leopard, crocodile
#
# 'lizard': dinosaur, snake, kangaroo, crocodile, raccoon
#
# 'lobster': sweet_pepper, cake, sandwich, dish, bread
#
# 'maple_tree': oak_tree, palm_tree, forest, willow_tree, bush
#
# 'mushroom': worm, snail, skunk, dirt, poppy
#
# 'oak_tree': palm_tree, forest, willow_tree, maple_tree, pine_tree
#
# 'orchid': rose, tulip, design, sunflower, purple
#
# 'otter': shark, crab, turtle, ray, beaver
#
# 'palm_tree': oak_tree, willow_tree, maple_tree, forest, tree
#
# 'pear': fruit, basket, banana, container, bananas
#
# 'pickup_truck': streetcar, wheels, tractor, truck, windshield
#
# 'pine_tree': willow_tree, oak_tree, forest, palm_tree, trees
#
# 'plain': pine_tree, ground, willow_tree, skunk, forest
#
# 'poppy': sunflower, worm, mushroom, snail, tulip
#
# 'porcupine': skunk, possum, shrew, squirrel, kangaroo
#
# 'possum': shrew, porcupine, skunk, raccoon, squirrel
#
# 'rabbit': hamster, crocodile, wolf, fox, dinosaur
#
# 'raccoon': snake, crocodile, lizard, kangaroo, dinosaur
#
# 'ray': flatfish, otter, turtle, shark, crab
#
# 'rocket': airplane, plane, jet, engine, tractor
#
# 'rose': tulip, orchid, flowers, sunflower, poppy
#
# 'sea': whale, shark, dolphin, ocean, trout
#
# 'seal': sand, crab, turtle, beach, otter
#
# 'shark': sea, whale, otter, dolphin, trout
#
# 'shrew': possum, skunk, porcupine, hamster, raccoon
#
# 'skunk': porcupine, shrew, possum, squirrel, beetle
#
# 'skyscraper': castle, building, roof, buildings, windows
#
# 'snail': mushroom, worm, poppy, grass, forest
#
# 'snake': lizard, dinosaur, raccoon, crocodile, kangaroo
#
# 'spider': beetle, skunk, shrew, possum, porcupine
#
# 'squirrel': porcupine, skunk, possum, forest, shrew
#
# 'streetcar': train, bus, car, vehicle, tractor
#
# 'sunflower': poppy, butterfly, tulip, rose, large
#
# 'sweet_pepper': bread, sandwich, pizza, lobster, plate
#
# 'telephone': television, keyboard, laptop, monitor, screen
#
# 'television': telephone, monitor, laptop, keyboard, computer
#
# 'tiger': leopard, lion, wolf, fox, rabbit
#
# 'tractor': lawn_mower, streetcar, vehicle, pickup_truck, wheels
#
# 'trout': water, sea, dolphin, shark, crab
#
# 'tulip': rose, orchid, poppy, flowers, sunflower
#
# 'turtle': crab, sand, seal, otter, beach
#
# 'wardrobe': coat, jacket, hat, sweater, pants
#
# 'whale': sea, shark, dolphin, ocean, trout
#
# 'willow_tree': oak_tree, palm_tree, pine_tree, forest, maple_tree
#
# 'wolf': fox, leopard, rabbit, hamster, tiger
#
# 'worm': mushroom, snail, forest, grass, skunk
#
# ================================================================================

# %%
# =============================================================================
# STAGE 9: SAVE & VERIFY FINAL MODEL
# =============================================================================
# Our experiment is complete! We have a new, larger embedding matrix
# and vocabulary list. Let's save these to a new .pth file so we
# can use them in other applications without re-running the GA.
#
# We will then immediately reload the file to verify it saved correctly.

print("\n[STAGE 9] Saving and Verifying Final Artifacts")
print("-" * 70)

# --- 1. Define Save Path ---
save_path = "best_skipgram_523words.pth"

print(all_vocab)

# --- 2. Combine and Save ---
# We are not saving the original PyTorch model, but rather the *results*
# of our process: the combined embedding matrix and the new vocab list.

# Combine the original 'embeddings' and our new 'inserted_embeddings'
full_embeddings = np.vstack([embeddings, inserted_embeddings])
full_embeddings_tensor = torch.tensor(full_embeddings, dtype=torch.float32)

#MEGETHOS
assert full_embeddings.shape[0] == len(all_vocab)

#2) Original vocab mapping
for i, w in enumerate(nodes[:10]):
    assert np.allclose(full_embeddings[i], embeddings[i])

#3) Inserted words mapping
N = len(nodes)
for i, w in enumerate(missing_cifar_words[:10]):
    assert np.allclose(full_embeddings[N + i], inserted_embeddings[i])

#4) Round-trip vocab check
vocab = {w:i for i,w in enumerate(all_vocab)}
for i, w in enumerate(all_vocab[:10]):
    assert vocab[w] == i

print(f"Saving combined model to {save_path}...")
torch.save({
    # The (N+K, D) embedding matrix
    'embeddings': full_embeddings_tensor,

    # The (N+K) vocabulary list
    'vocab': all_vocab,

    # Just the list of words we inserted
    'inserted_words': missing_cifar_words,

    # Metadata for quick loading
    'metadata': {
        'n_original': len(nodes),
        'n_inserted': len(missing_cifar_words),
        'vocab_size': len(all_vocab),
        'embedding_dim': inserted_embeddings.shape[1]
    }
}, save_path)

print(f"✓ Model saved to: {save_path}")

# ============================================================================
# VERIFICATION: RELOAD AND TEST
# ============================================================================
# Let's confirm the file is valid by loading it and running the
# neighbor-finding test on both original *and* inserted words.

print("\nReloading model for verification...")

# --- 1. Reload Checkpoint ---
checkpoint = torch.load(save_path, map_location='cpu')
loaded_embeddings = checkpoint['embeddings'].numpy()
loaded_vocab = checkpoint['vocab']
loaded_inserted = checkpoint['inserted_words']

print(f"✓ Model reloaded. Vocab: {len(loaded_vocab)}, Inserted: {len(loaded_inserted)}")

# --- 2. Run Vocabulary Test ---
# This test now includes our newly evolved words.
print("\n" + "="*70)
print("Final Vocabulary Test (Original + Inserted)")
print("="*70)

# We'll test a mix of original words and our new target words
test_words = [
    'man', 'woman', 'dog', 'car', 'blue',  # Original words
] + missing_cifar_words  # Our new words

for word in test_words:
    if word not in loaded_vocab:
        print(f"   '{word:10s}' → Not in vocabulary.")
        continue

    # Find the word's index and vector
    idx = loaded_vocab.index(word)
    norm = np.linalg.norm(loaded_embeddings[idx])

    # Use lab6's 'find_similar_words' on our fully combined data
    similar = find_similar_words(word, loaded_vocab, loaded_embeddings, top_k=5)

    if not similar:
        print(f"   '{word:10s}' → idx={idx:4d}, norm={norm:.4f} (No neighbors found?)")
        continue

    neighbor_str = ', '.join([f"{w}({s:.3f})" for w, s in similar])

    print(f"   '{word:10s}' → idx={idx:4d}, norm={norm:.4f}")
    print(f"      Similar: {neighbor_str}\n")

print("\n" + "="*70)
print("✓ Vocabulary Test Complete")
print("="*70)
# Out:
# [STAGE 9] Saving and Verifying Final Artifacts
# ----------------------------------------------------------------------
# ['a', 'the', 'on', 'of', 'is', 'in', 'white', 'black', 'and', 'man', 'with', 'blue', 'red', 'green', 'wearing', 'brown', 'building', 'are', 'person', 'woman', 'this', 'wall', 'sky', 'window', 'yellow', 'shirt', 'sign', 'water', 'table', 'to', 'has', 'tree', 'light', 'train', 'two', 'grass', 'an', 'side', 'large', 'small', 'street', 'front', 'ground', 'top', 'plate', 'car', 'part', 'orange', 'head', 'clouds', 'wooden', 'standing', 'bus', 'pole', 'sitting', 'metal', 'behind', 'holding', 'color', 'trees', 'silver', 'snow', 'gray', 'people', 'dog', 'hand', 'road', 'tennis', 'hair', 'grey', 'dark', 'glass', 'at', 'plane', 'back', 'floor', 'cat', 'background', 'fence', 'clock', 'door', 'giraffe', 'leaves', 'boy', 'left', 'field', 'right', 'next', 'long', 'by', 'bear', 'chair', 'elephant', 'tall', 'pink', "man's", 'girl', 'horse', 'pizza', 'for', 'baseball', 'zebra', 'pants', 'hat', 'boat', 'truck', 'walking', 'jacket', 'bench', 'sidewalk', 'it', 'hanging', 'toilet', 'up', 'bird', 'tail', 'bed', 'parked', 'down', 'near', 'wood', 'board', 'from', 'colored', 'ear', 'windows', 'clear', 'face', 'motorcycle', 'under', 'umbrella', 'leg', 'player', 'line', 'over', 'helmet', 'picture', 'food', 'eye', 'bag', 'beach', 'nose', 'bowl', 'handle', 'brick', 'air', 'paper', 'shadow', 'cow', 'skateboard', 'three', 'shorts', 'tracks', 'bottle', 'bike', 'that', 'sheep', 'ball', 'lights', 'wheel', 'short', 'letter', 'round', 'above', 'number', 'tan', 'plastic', 'edge', 'open', 'his', 'kite', 'box', 'phone', 'dirt', 'distance', 'ski', 'shoes', 'flowers', 'surfboard', 'cake', 'piece', 'around', 'desk', 'airplane', 'sink', 'mirror', 'counter', 'house', 'post', 'traffic', 'made', 'arm', "woman's", 'laptop', 'pair', 'computer', 'ocean', 'purple', 'sand', 'lamp', 'young', 'glasses', 'big', 'legs', 'bathroom', 'covered', 'looking', 'cup', 'photo', 'flower', 'one', 'roof', 'vase', 'cap', 'riding', 'tower', 'out', 'lines', 'shelf', 'trunk', 'some', 'tire', 'shoe', 'area', 'jeans', 'playing', 'there', 'racket', 'logo', 'court', 'tile', 'painted', 'rock', 'flying', 'room', 'bottom', 'neck', 'seat', 'stone', 'frisbee', 'group', 'bright', 'hydrant', 'child', 'mouth', 'stop', 'fire', 'outside', 'baby', 'kitchen', 'reflection', 'tie', 'plant', 'patch', 'wave', 'foot', 'little', 'ceiling', 'body', 'eyes', 'striped', 'hill', 'keyboard', 'laying', 'mountain', 'lady', 'concrete', 'pillow', 'these', 'old', 'flag', 'inside', 'gold', 'vehicle', 'four', 'hands', 'teddy', 'coat', 'can', 'wheels', 'letters', 'parking', 'leaf', 'rocks', 'banana', 'suit', 'stripes', 'couch', 'no', 'stripe', 'writing', 'frame', 'eating', 'bat', 'row', 'waves', 'wine', 'her', 'corner', 'off', 'wing', 'camera', 'stand', 'screen', 'cars', 'along', 'book', 'sandwich', 'animal', 'towel', 'coffee', 'wet', 'beside', 'bicycle', 'men', 'fork', 'cabinet', 'empty', 'knife', 'square', 'container', 'skier', 'sunglasses', 'park', 'feet', 'spot', 't', 'city', 'pot', 'attached', 'design', 'basket', 'very', 'cheese', 'buildings', 'button', 'against', 'dress', 'surfer', 'guy', 'stove', 'slice', 'suitcase', 'engine', 'bananas', 'growing', 'game', 'poles', 'bush', 'wrist', 'bridge', 'tray', 'many', 'cloud', 'cell', 'middle', 'ears', 'signs', 'through', 'oven', 'windshield', 'track', 'hot', 'van', 'carrying', 'glove', 'lot', 'scene', 'watching', 'other', 'elephants', 'bread', 'surface', 'apple', 'mouse', 'section', 'view', 'zebras', 'full', 'chain', 'cloudy', 'broccoli', 'end', 'base', 'bunch', 'giraffes', 'sun', 'several', 'fruit', 'tv', 'between', 'being', 'trash', 'wears', 'lid', 'worn', 'skis', 'railing', 'colorful', 'jet', 'blanket', 'dish', 'cloth', 'branches', 'branch', 'rear', 'visible', 'collar', 'watch', 'bushes', 'remote', 'pavement', 'wire', 'cover', 'set', 'beige', 'horses', 'passenger', 'fur', 'blonde', 'into', 'donut', 'platform', 'display', 'backpack', 'tag', 'napkin', 'cement', 'sweater', 'monitor', 'curtain', 'stuffed', 'tank', 'closed', 'pile', 'word', 'have', 'rack', 'taken', 'mountains', 'sauce',  ...
# Saving combined model to best_skipgram_523words.pth...
# ✓ Model saved to: best_skipgram_523words.pth
#
# Reloading model for verification...
# ✓ Model reloaded. Vocab: 523, Inserted: 68
#
# ======================================================================
# Final Vocabulary Test (Original + Inserted)
# ======================================================================
#    'man       ' → idx=   9, norm=1.4181
#       Similar: woman(0.955), person(0.943), guy(0.923), lady(0.910), boy(0.889)
#
#    'woman     ' → idx=  19, norm=1.4987
#       Similar: man(0.955), lady(0.950), guy(0.947), person(0.936), girl(0.934)
#
#    'dog       ' → idx=  64, norm=1.5306
#       Similar: bear(0.936), cat(0.918), animal(0.913), cow(0.894), wolf(0.892)
#
#    'car       ' → idx=  45, norm=1.5639
#       Similar: vehicle(0.967), van(0.954), truck(0.938), streetcar(0.938), bus(0.931)
#
#    'blue      ' → idx=  11, norm=1.3646
#       Similar: red(0.934), white(0.931), purple(0.907), yellow(0.906), colorful(0.906)
#
#    'aquarium_fish' → idx= 455, norm=1.7007
#       Similar: trout(0.935), water(0.929), bottle(0.888), lobster(0.883), boat(0.873)
#
#    'beaver    ' → idx= 456, norm=1.7046
#       Similar: otter(0.932), crocodile(0.931), flatfish(0.929), snake(0.929), lizard(0.919)
#
#    'bee       ' → idx= 457, norm=1.7070
#       Similar: butterfly(0.949), rocket(0.865), sunflower(0.863), ray(0.849), lawn_mower(0.834)
#
#    'beetle    ' → idx= 458, norm=1.7077
#       Similar: spider(0.964), skunk(0.964), shrew(0.956), cockroach(0.952), lizard(0.946)
#
#    'butterfly ' → idx= 459, norm=1.7048
#       Similar: bee(0.949), sunflower(0.941), design(0.910), tulip(0.905), poppy(0.904)
#
#    'camel     ' → idx= 460, norm=1.7074
#       Similar: cow(0.981), zebra(0.966), giraffe(0.965), sheep(0.965), cattle(0.954)
#
#    'castle    ' → idx= 461, norm=1.7094
#       Similar: skyscraper(0.963), building(0.963), bridge(0.923), roof(0.917), tower(0.909)
#
#    'caterpillar' → idx= 462, norm=1.7042
#       Similar: maple_tree(0.959), leaves(0.956), palm_tree(0.953), leaf(0.951), plant(0.944)
#
#    'cattle    ' → idx= 463, norm=1.7074
#       Similar: camel(0.954), cow(0.939), shrew(0.932), skunk(0.930), porcupine(0.930)
#
#    'chimpanzee' → idx= 464, norm=1.7046
#       Similar: face(0.941), head(0.939), lion(0.938), dinosaur(0.929), raccoon(0.928)
#
#    'cockroach ' → idx= 465, norm=1.7023
#       Similar: beetle(0.952), mushroom(0.930), worm(0.926), skunk(0.915), beaver(0.915)
#
#    'crab      ' → idx= 466, norm=1.7122
#       Similar: turtle(0.979), seal(0.969), sand(0.964), otter(0.950), trout(0.941)
#
#    'crocodile ' → idx= 467, norm=1.7024
#       Similar: dinosaur(0.980), lizard(0.979), raccoon(0.974), kangaroo(0.969), rabbit(0.968)
#
#    'dinosaur  ' → idx= 468, norm=1.7047
#       Similar: lizard(0.987), snake(0.981), crocodile(0.980), lion(0.974), raccoon(0.969)
#
#    'dolphin   ' → idx= 469, norm=1.7016
#       Similar: ocean(0.969), sea(0.968), whale(0.962), shark(0.958), waves(0.957)
#
#    'flatfish  ' → idx= 470, norm=1.6985
#       Similar: ray(0.947), crab(0.940), beaver(0.929), seal(0.929), otter(0.928)
#
#    'forest    ' → idx= 471, norm=1.7058
#       Similar: oak_tree(0.987), willow_tree(0.981), palm_tree(0.980), maple_tree(0.977), pine_tree(0.973)
#
#    'fox       ' → idx= 472, norm=1.7040
#       Similar: wolf(0.976), rabbit(0.964), leopard(0.953), hamster(0.947), tiger(0.947)
#
#    'hamster   ' → idx= 473, norm=1.7095
#       Similar: rabbit(0.972), lizard(0.965), crocodile(0.963), kangaroo(0.963), raccoon(0.963)
#
#    'kangaroo  ' → idx= 474, norm=1.7082
#       Similar: lizard(0.982), raccoon(0.971), crocodile(0.969), dinosaur(0.967), snake(0.965)
#
#    'lawn_mower' → idx= 475, norm=1.7073
#       Similar: tractor(0.971), skunk(0.914), beetle(0.911), worm(0.909), cockroach(0.908)
#
#    'leopard   ' → idx= 476, norm=1.7075
#       Similar: tiger(0.973), wolf(0.967), lion(0.966), rabbit(0.959), lizard(0.956)
#
#    'lion      ' → idx= 477, norm=1.7060
#       Similar: dinosaur(0.974), lizard(0.968), tiger(0.966), leopard(0.966), crocodile(0.961)
#
#    'lizard    ' → idx= 478, norm=1.7038
#       Similar: dinosaur(0.987), snake(0.984), kangaroo(0.982), crocodile(0.979), raccoon(0.974)
#
#    'lobster   ' → idx= 479, norm=1.7054
#       Similar: sweet_pepper(0.950), cake(0.946), sandwich(0.932), dish(0.923), bread(0.921)
#
#    'maple_tree' → idx= 480, norm=1.7094
#       Similar: oak_tree(0.983), palm_tree(0.981), forest(0.977), willow_tree(0.974), bush(0.964)
#
#    'mushroom  ' → idx= 481, norm=1.7120
#       Similar: worm(0.983), snail(0.982), skunk(0.949), dirt(0.948), poppy(0.948)
#
#    'oak_tree  ' → idx= 482, norm=1.7070
#       Similar: palm_tree(0.990), forest(0.987), willow_tree(0.987), maple_tree(0.983), pine_tree(0.978)
#
#    'orchid    ' → idx= 483, norm=1.7077
#       Similar: rose(0.976), tulip(0.972), design(0.937), sunflower(0.908), purple(0.907)
#
#    'otter     ' → idx= 484, norm=1.7102
#       Similar: shark(0.958), crab(0.950), turtle(0.937), ray(0.936), beaver(0.932)
#
#    'palm_tree ' → idx= 485, norm=1.7049
#       Similar: oak_tree(0.990), willow_tree(0.981), maple_tree(0.981), forest(0.980), tree(0.973)
#
#    'pear      ' → idx= 486, norm=1.7108
#       Similar: fruit(0.952), basket(0.928), banana(0.924), container(0.912), bananas(0.912)
#
#    'pickup_truck' → idx= 487, norm=1.7094
#       Similar: streetcar(0.911), wheels(0.908), tractor(0.904), truck(0.903), windshield(0.902)
#
#    'pine_tree ' → idx= 488, norm=1.7081
#       Similar: willow_tree(0.981), oak_tree(0.978), forest(0.973), palm_tree(0.971), trees(0.966)
#
#    'plain     ' → idx= 489, norm=1.7081
#       Similar: pine_tree(0.935), ground(0.932), willow_tree(0.929), skunk(0.928), forest(0.921)
#
#    'poppy     ' → idx= 490, norm=1.7079
#       Similar: sunflower(0.969), worm(0.949), mushroom(0.948), snail(0.940), tulip(0.931)
#
#    'porcupine ' → idx= 491, norm=1.7072
#       Similar: skunk(0.984), possum(0.982), shrew(0.974), squirrel(0.973), kangaroo(0.954)
#
#    'possum    ' → idx= 492, norm=1.6996
#       Similar: shrew(0.987), porcupine(0.982), skunk(0.972), raccoon(0.965), squirrel(0.963)
#
#    'rabbit    ' → idx= 493, norm=1.7046
#       Similar: hamster(0.972), crocodile(0.968), wolf(0.967), fox(0.964), dinosaur(0.963)
#
#    'raccoon   ' → idx= 494, norm=1.7000
#       Similar: snake(0.977), crocodile(0.974), lizard(0.974), kangaroo(0.971), dinosaur(0.969)
#
#    'ray       ' → idx= 495, norm=1.7063
#       Similar: flatfish(0.947), otter(0.936), turtle(0.924), shark(0.917), crab(0.913)
#
#    'rocket    ' → idx= 496, norm=1.7055
#       Similar: airplane(0.925), plane(0.922), jet(0.912), engine(0.897), tractor(0.889)
#
#    'rose      ' → idx= 497, norm=1.7037
#       Similar: tulip(0.985), orchid(0.976), flowers(0.917), sunflower(0.915), poppy(0.913)
#
#    'sea       ' → idx= 498, norm=1.7079
#       Similar: whale(0.991), shark(0.973), dolphin(0.968), ocean(0.958), trout(0.953)
#
#    'seal      ' → idx= 499, norm=1.7033
#       Similar: sand(0.971), crab(0.969), turtle(0.941), beach(0.935), otter(0.930)
#
#    'shark     ' → idx= 500, norm=1.7114
#       Similar: sea(0.973), whale(0.968), otter(0.958), dolphin(0.958), trout(0.943)
#
#    'shrew     ' → idx= 501, norm=1.6957
#       Similar: possum(0.987), skunk(0.977), porcupine(0.974), hamster(0.959), raccoon(0.956)
#
#    'skunk     ' → idx= 502, norm=1.7035
#       Similar: porcupine(0.984), shrew(0.977), possum(0.972), squirrel(0.969), beetle(0.964)
#
#    'skyscraper' → idx= 503, norm=1.7046
#       Similar: castle(0.963), building(0.954), roof(0.918), buildings(0.915), windows(0.914)
#
#    'snail     ' → idx= 504, norm=1.7065
#       Similar: mushroom(0.982), worm(0.967), poppy(0.940), grass(0.937), forest(0.934)
#
#    'snake     ' → idx= 505, norm=1.7039
#       Similar: lizard(0.984), dinosaur(0.981), raccoon(0.977), crocodile(0.966), kangaroo(0.965)
#
#    'spider    ' → idx= 506, norm=1.7095
#       Similar: beetle(0.964), skunk(0.961), shrew(0.953), possum(0.950), porcupine(0.946)
#
#    'squirrel  ' → idx= 507, norm=1.7057
#       Similar: porcupine(0.973), skunk(0.969), possum(0.963), forest(0.953), shrew(0.949)
#
#    'streetcar ' → idx= 508, norm=1.7103
#       Similar: train(0.952), bus(0.950), car(0.938), vehicle(0.924), tractor(0.915)
#
#    'sunflower ' → idx= 509, norm=1.7097
#       Similar: poppy(0.969), butterfly(0.941), tulip(0.921), rose(0.915), large(0.912)
#
#    'sweet_pepper' → idx= 510, norm=1.7052
#       Similar: bread(0.972), sandwich(0.968), pizza(0.952), lobster(0.950), plate(0.940)
#
#    'telephone ' → idx= 511, norm=1.7052
#       Similar: television(0.969), keyboard(0.958), laptop(0.956), monitor(0.949), screen(0.939)
#
#    'television' → idx= 512, norm=1.7065
#       Similar: telephone(0.969), monitor(0.964), laptop(0.962), keyboard(0.952), computer(0.948)
#
#    'tiger     ' → idx= 513, norm=1.7061
#       Similar: leopard(0.973), lion(0.966), wolf(0.959), fox(0.947), rabbit(0.946)
#
#    'tractor   ' → idx= 514, norm=1.7100
#       Similar: lawn_mower(0.971), streetcar(0.915), vehicle(0.909), pickup_truck(0.904), wheels(0.900)
#
#    'trout     ' → idx= 515, norm=1.7072
#       Similar: water(0.960), sea(0.953), dolphin(0.952), shark(0.943), crab(0.941)
#
#    'tulip     ' → idx= 516, norm=1.7083
#       Similar: rose(0.985), orchid(0.972), poppy(0.931), flowers(0.924), sunflower(0.921)
#
#    'turtle    ' → idx= 517, norm=1.7086
#       Similar: crab(0.979), sand(0.941), seal(0.941), otter(0.937), beach(0.933)
#
#    'wardrobe  ' → idx= 518, norm=1.7015
#       Similar: coat(0.959), jacket(0.959), hat(0.955), sweater(0.951), pants(0.949)
#
#    'whale     ' → idx= 519, norm=1.7043
#       Similar: sea(0.991), shark(0.968), dolphin(0.962), ocean(0.955), trout(0.937)
#
#    'willow_tree' → idx= 520, norm=1.7064
#       Similar: oak_tree(0.987), palm_tree(0.981), pine_tree(0.981), forest(0.981), maple_tree(0.974)
#
#    'wolf      ' → idx= 521, norm=1.7057
#       Similar: fox(0.976), leopard(0.967), rabbit(0.967), hamster(0.963), tiger(0.959)
#
#    'worm      ' → idx= 522, norm=1.7063
#       Similar: mushroom(0.983), snail(0.967), forest(0.963), grass(0.956), skunk(0.956)
#
#
# ======================================================================
# ✓ Vocabulary Test Complete
# ======================================================================

# %%
# ============================================================================
# VERIFICATION: RELOAD AND TEST
# ============================================================================
# Let's confirm the file is valid by loading it and running the
# neighbor-finding test on both original *and* inserted words.

print("\nReloading model for verification...")

# --- 1. Reload Checkpoint ---
save_path = "best_skipgram_523words.pth"
checkpoint = torch.load(save_path, map_location='cpu')
loaded_embeddings = checkpoint['embeddings'].numpy()
loaded_vocab = checkpoint['vocab']
loaded_inserted = checkpoint['inserted_words']

print(f"✓ Model reloaded. Vocab: {len(loaded_vocab)}, Inserted: {len(loaded_inserted)}")

# --- 2. Run Vocabulary Test ---
# This test now includes our newly evolved words.
print("\n" + "="*70)
print("Final Vocabulary Test (Original + Inserted)")
print("="*70)

# We'll test a mix of original words and our new target words
test_words = [
    'man', 'woman', 'dog', 'car', 'blue',  # Original words
] + missing_cifar_words  # Our new words

for word in test_words:
    if word not in loaded_vocab:
        print(f"   '{word:10s}' → Not in vocabulary.")
        continue

    # Find the word's index and vector
    idx = loaded_vocab.index(word)
    norm = np.linalg.norm(loaded_embeddings[idx])

    # Use lab6's 'find_similar_words' on our fully combined data
    similar = find_similar_words(word, loaded_vocab, loaded_embeddings, top_k=5)

    if not similar:
        print(f"   '{word:10s}' → idx={idx:4d}, norm={norm:.4f} (No neighbors found?)")
        continue

    neighbor_str = ', '.join([f"{w}({s:.3f})" for w, s in similar])

    print(f"   '{word:10s}' → idx={idx:4d}, norm={norm:.4f}")
    print(f"      Similar: {neighbor_str}\n")

print("\n" + "="*70)
print("✓ Vocabulary Test Complete")
print("="*70)
# Out:
# Reloading model for verification...
# ✓ Model reloaded. Vocab: 523, Inserted: 68
#
# ======================================================================
# Final Vocabulary Test (Original + Inserted)
# ======================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 27
#      22 print("="*70)
#      24 # We'll test a mix of original words and our new target words
#      25 test_words = [
#      26     'man', 'woman', 'dog', 'car', 'blue',  # Original words
# ---> 27 ] + missing_cifar_words  # Our new words
#      29 for word in test_words:
#      30     if word not in loaded_vocab:
#
# NameError: name 'missing_cifar_words' is not defined

# %%
# =============================================================================
# STAGE 10: VISUALIZATION & FINAL SUMMARY
# =================================_===========================================
#
# Our final step is to visualize the combined embedding space using t-SNE.
# This special visualization function will highlight our newly inserted
# words in red, allowing us to *visually inspect* whether they landed in
# semantically appropriate regions of the space.
#
# e.g., Did 'wolf' and 'tiger' land near other 'animal' words?
#       Did 'rocket' land near 'plane'?
#       Did 'castle' land near 'building' or 'house'?

print("\n[STAGE 10] Visualizing Combined Embedding Space")
print("-" * 70)

visualize_with_inserted_words(
    nodes=all_vocab,
    embeddings=all_embeddings,
    inserted_words=missing_cifar_words,
    output_file="embeddings_with_inserted.png",
    sample_size=500  # Sample 500 words, including all our inserted ones
)

# --- 11. Final Summary ---
# Finally, let's print a summary of the entire run.

print("\n" + "="*70)
print("✓ PIPELINE COMPLETE")
print("="*70)

print(f"Inserted words: {', '.join(missing_cifar_words)}")
print(f"New vocabulary size: {len(all_vocab)} words")

print("\n💡 Key Insights:")
print(f"  • (1+{ga_pop_size}) ES successfully evolved {len(missing_cifar_words)} embeddings.")
print("  • The Lab 6 analysis report (Stage 8) quantitatively checks quality.")
print("  • The t-SNE plot above (Stage 10) visually confirms semantic coherence.")
print("="*70)
# Out:
# [STAGE 10] Visualizing Combined Embedding Space
# ----------------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 18
#      14 print("\n[STAGE 10] Visualizing Combined Embedding Space")
#      15 print("-" * 70)
#      17 visualize_with_inserted_words(
# ---> 18     nodes=all_vocab,
#      19     embeddings=all_embeddings,
#      20     inserted_words=missing_cifar_words,
#      21     output_file="embeddings_with_inserted.png",
#      22     sample_size=500  # Sample 500 words, including all our inserted ones
#      23 )
#      25 # --- 11. Final Summary ---
#      26 # Finally, let's print a summary of the entire run.
#      28 print("\n" + "="*70)
#
# NameError: name 'all_vocab' is not defined

# %%
from src.cw2 import build_my_embeddings
from src.lab6_current_best import find_similar_words


import os
import random
import numpy as np
import torch

import math
import re
from collections import Counter
from typing import Dict, Set, Optional


print("\n[TEST] Loading embeddings...")
vocab, E = build_my_embeddings("best_skipgram_523words.pth")

nodes = list(vocab.keys()) 

print(f"✓ Loaded vocab size: {len(vocab)}")
print(f"✓ Embedding matrix shape: {E.shape}")

# ------------------------------------------------------------
# CIFAR-100 sanity check (subset)
# ------------------------------------------------------------
cifar_probe = [
        "airplane", "apple", "bear", "camel",
        "clock", "keyboard", "train", "tractor"
]

print("\n[TEST] CIFAR words presence + norms")
for w in cifar_probe:
    if w not in vocab:
        raise ValueError(f"CIFAR word missing: {w}")
    idx = vocab[w]
    print(f"  {w:12s} idx={idx:4d} norm={np.linalg.norm(E[idx]):.4f}")

# ------------------------------------------------------------
# Random round-trip check
# ------------------------------------------------------------
print("\n[TEST] Random round-trip index check")
for w in list(vocab.keys())[:10]:
    idx = vocab[w]
    assert np.allclose(E[idx], E[vocab[w]])
print("✓ Round-trip mapping OK")

# ------------------------------------------------------------
# Cosine similarity sanity (no NaNs)
# ------------------------------------------------------------
sims = np.dot(E[:50], E[:50].T)
if np.isnan(sims).any():
    raise ValueError("NaNs detected in similarity matrix")

print("\n✓ ALL CHECKS PASSED — MODEL IS SUBMISSION-READY ✅")



# Sample 100 random words from vocabulary
random.seed(42)  # reproducibility
test_words = random.sample(nodes, min(100, len(nodes)))


N = 455  # number of original Visual Genome words
inserted_words = nodes[N:]

print("=" * 80)
print("NEAREST NEIGHBORS (100 RANDOM WORDS)")
print("=" * 80)

for word in nodes:
    print(f"\nMost similar to '{word}':")
    neighbors = find_similar_words(word, nodes, E, top_k=8)

    if not neighbors:
        print("  (No neighbors found)")
        continue

    for nb, sim in neighbors:
        print(f"  {nb:<18s} similarity={sim:.4f}")
# Out:
# [TEST] Loading embeddings...
# ✓ Loaded vocab size: 523
# ✓ Embedding matrix shape: (523, 96)
#
# [TEST] CIFAR words presence + norms
#   airplane     idx= 183 norm=1.8580
#   apple        idx= 373 norm=1.7192
#   bear         idx=  90 norm=1.7016
#   camel        idx= 460 norm=1.7074
#   clock        idx=  79 norm=1.6388
#   keyboard     idx= 262 norm=1.9388
#   train        idx=  33 norm=1.6313
#   tractor      idx= 514 norm=1.7100
#
# [TEST] Random round-trip index check
# ✓ Round-trip mapping OK
#
# ✓ ALL CHECKS PASSED — MODEL IS SUBMISSION-READY ✅
# ================================================================================
# NEAREST NEIGHBORS (100 RANDOM WORDS)
# ================================================================================
#
# Most similar to 'a':
#   can                similarity=0.7962
#   he                 similarity=0.7072
#   her                similarity=0.6918
#   has                similarity=0.6392
#   to                 similarity=0.6270
#   is                 similarity=0.6077
#   these              similarity=0.6040
#   by                 similarity=0.5970
#
# Most similar to 'the':
#   this               similarity=0.7267
#   his                similarity=0.7264
#   he                 similarity=0.6945
#   her                similarity=0.6895
#   can                similarity=0.6447
#   and                similarity=0.6198
#   is                 similarity=0.6034
#   are                similarity=0.6016
#
# Most similar to 'on':
#   from               similarity=0.7155
#   at                 similarity=0.7003
#   an                 similarity=0.6588
#   to                 similarity=0.6272
#   in                 similarity=0.6205
#   her                similarity=0.6183
#   is                 similarity=0.6173
#   these              similarity=0.5913
#
# Most similar to 'of':
#   to                 similarity=0.7491
#   from               similarity=0.7004
#   by                 similarity=0.6994
#   it                 similarity=0.6798
#   is                 similarity=0.6793
#   in                 similarity=0.6689
#   has                similarity=0.6530
#   this               similarity=0.6054
#
# Most similar to 'is':
#   to                 similarity=0.8244
#   he                 similarity=0.7356
#   has                similarity=0.7283
#   in                 similarity=0.7208
#   her                similarity=0.7181
#   an                 similarity=0.6893
#   from               similarity=0.6837
#   of                 similarity=0.6793
#
# Most similar to 'in':
#   it                 similarity=0.7689
#   is                 similarity=0.7208
#   are                similarity=0.6929
#   to                 similarity=0.6863
#   of                 similarity=0.6689
#   that               similarity=0.6601
#   from               similarity=0.6553
#   an                 similarity=0.6512
#
# Most similar to 'white':
#   black              similarity=0.9488
#   red                similarity=0.9348
#   blue               similarity=0.9311
#   green              similarity=0.9172
#   there              similarity=0.9093
#   gold               similarity=0.9053
#   colorful           similarity=0.9044
#   four               similarity=0.9019
#
# Most similar to 'black':
#   white              similarity=0.9488
#   red                similarity=0.9209
#   two                similarity=0.8999
#   one                similarity=0.8920
#   blue               similarity=0.8918
#   shadow             similarity=0.8895
#   brown              similarity=0.8884
#   pair               similarity=0.8872
#
# Most similar to 'and':
#   he                 similarity=0.7560
#   an                 similarity=0.7323
#   with               similarity=0.6452
#   for                similarity=0.6387
#   the                similarity=0.6198
#   this               similarity=0.6016
#   a                  similarity=0.5651
#   on                 similarity=0.5600
#
# Most similar to 'man':
#   woman              similarity=0.9549
#   person             similarity=0.9434
#   guy                similarity=0.9231
#   lady               similarity=0.9097
#   boy                similarity=0.8893
#   girl               similarity=0.8865
#   pair               similarity=0.8861
#   child              similarity=0.8796
#
# Most similar to 'with':
#   by                 similarity=0.7338
#   can                similarity=0.6873
#   this               similarity=0.6665
#   for                similarity=0.6549
#   and                similarity=0.6452
#   it                 similarity=0.6141
#   of                 similarity=0.5936
#   a                  similarity=0.5781
#
# Most similar to 'blue':
#   red                similarity=0.9336
#   white              similarity=0.9311
#   purple             similarity=0.9073
#   yellow             similarity=0.9062
#   colorful           similarity=0.9056
#   orange             similarity=0.9051
#   green              similarity=0.8969
#   part               similarity=0.8921
#
# Most similar to 'red':
#   yellow             similarity=0.9504
#   orange             similarity=0.9371
#   white              similarity=0.9348
#   blue               similarity=0.9336
#   green              similarity=0.9216
#   black              similarity=0.9209
#   purple             similarity=0.9162
#   colorful           similarity=0.8985
#
# Most similar to 'green':
#   red                similarity=0.9216
#   orange             similarity=0.9188
#   yellow             similarity=0.9188
#   white              similarity=0.9172
#   sunflower          similarity=0.9002
#   colorful           similarity=0.8987
#   blue               similarity=0.8969
#   purple             similarity=0.8942
#
# Most similar to 'wearing':
#   wears              similarity=0.8822
#   dress              similarity=0.8686
#   shirt              similarity=0.8516
#   wardrobe           similarity=0.8425
#   pants              similarity=0.8368
#   suit               similarity=0.8323
#   shorts             similarity=0.8173
#   jacket             similarity=0.8135
#
# Most similar to 'brown':
#   tan                similarity=0.9224
#   white              similarity=0.9013
#   black              similarity=0.8884
#   green              similarity=0.8872
#   beige              similarity=0.8793
#   shadow             similarity=0.8692
#   one                similarity=0.8677
#   there              similarity=0.8670
#
# Most similar to 'building':
#   castle             similarity=0.9633
#   skyscraper         similarity=0.9535
#   roof               similarity=0.9277
#   house              similarity=0.9171
#   buildings          similarity=0.9065
#   bridge             similarity=0.8947
#   sidewalk           similarity=0.8786
#   sign               similarity=0.8769
#
# Most similar to 'are':
#   an                 similarity=0.7456
#   in                 similarity=0.6929
#   can                similarity=0.6730
#   his                similarity=0.6346
#   the                similarity=0.6016
#   this               similarity=0.5894
#   at                 similarity=0.5624
#   is                 similarity=0.5503
#
# Most similar to 'person':
#   man                similarity=0.9434
#   guy                similarity=0.9386
#   woman              similarity=0.9360
#   lady               similarity=0.9074
#   boy                similarity=0.8978
#   child              similarity=0.8956
#   girl               similarity=0.8836
#   people             similarity=0.8336
#
# Most similar to 'woman':
#   man                similarity=0.9549
#   lady               similarity=0.9501
#   guy                similarity=0.9472
#   person             similarity=0.9360
#   girl               similarity=0.9345
#   boy                similarity=0.9129
#   child              similarity=0.9128
#   pair               similarity=0.8770
#
# Most similar to 'this':
#   by                 similarity=0.7842
#   these              similarity=0.7358
#   the                similarity=0.7267
#   it                 similarity=0.6705
#   with               similarity=0.6665
#   can                similarity=0.6613
#   his                similarity=0.6308
#   for                similarity=0.6274
#
# Most similar to 'wall':
#   floor              similarity=0.9242
#   ceiling            similarity=0.9131
#   room               similarity=0.8977
#   cabinet            similarity=0.8940
#   frame              similarity=0.8933
#   shelf              similarity=0.8880
#   bed                similarity=0.8853
#   sink               similarity=0.8667
#
# Most similar to 'sky':
#   whale              similarity=0.9078
#   plain              similarity=0.9033
#   sea                similarity=0.8975
#   clouds             similarity=0.8917
#   distance           similarity=0.8887
#   shark              similarity=0.8849
#   rocket             similarity=0.8770
#   ray                similarity=0.8668
#
# Most similar to 'window':
#   door               similarity=0.9008
#   castle             similarity=0.8915
#   skyscraper         similarity=0.8722
#   mirror             similarity=0.8686
#   windows            similarity=0.8662
#   wall               similarity=0.8531
#   building           similarity=0.8461
#   row                similarity=0.8389
#
# Most similar to 'yellow':
#   orange             similarity=0.9520
#   red                similarity=0.9504
#   green              similarity=0.9188
#   purple             similarity=0.9079
#   blue               similarity=0.9062
#   white              similarity=0.9003
#   colorful           similarity=0.8719
#   gold               similarity=0.8718
#
# Most similar to 'shirt':
#   wardrobe           similarity=0.9224
#   dress              similarity=0.9071
#   hair               similarity=0.8985
#   sweater            similarity=0.8940
#   jeans              similarity=0.8828
#   hat                similarity=0.8771
#   tie                similarity=0.8714
#   coat               similarity=0.8712
#
# Most similar to 'sign':
#   skyscraper         similarity=0.9094
#   signs              similarity=0.8955
#   city               similarity=0.8860
#   street             similarity=0.8854
#   streetcar          similarity=0.8837
#   lights             similarity=0.8821
#   road               similarity=0.8798
#   building           similarity=0.8769
#
# Most similar to 'water':
#   trout              similarity=0.9599
#   shark              similarity=0.9406
#   crab               similarity=0.9396
#   sea                similarity=0.9365
#   dolphin            similarity=0.9349
#   aquarium_fish      similarity=0.9291
#   otter              similarity=0.9246
#   flatfish           similarity=0.9219
#
# Most similar to 'table':
#   tray               similarity=0.9130
#   shelf              similarity=0.9068
#   box                similarity=0.8995
#   cup                similarity=0.8989
#   chair              similarity=0.8862
#   container          similarity=0.8813
#   dish               similarity=0.8758
#   coffee             similarity=0.8757
#
# Most similar to 'to':
#   is                 similarity=0.8244
#   has                similarity=0.7725
#   of                 similarity=0.7491
#   an                 similarity=0.7066
#   by                 similarity=0.7026
#   these              similarity=0.6990
#   in                 similarity=0.6863
#   can                similarity=0.6573
#
# Most similar to 'has':
#   to                 similarity=0.7725
#   is                 similarity=0.7283
#   from               similarity=0.6827
#   of                 similarity=0.6530
#   he                 similarity=0.6408
#   a                  similarity=0.6392
#   in                 similarity=0.6361
#   for                similarity=0.6149
#
# Most similar to 'tree':
#   palm_tree          similarity=0.9732
#   maple_tree         similarity=0.9603
#   oak_tree           similarity=0.9581
#   bush               similarity=0.9568
#   forest             similarity=0.9486
#   pine_tree          similarity=0.9445
#   willow_tree        similarity=0.9443
#   caterpillar        similarity=0.9392
#
# Most similar to 'light':
#   lights             similarity=0.8747
#   sign               similarity=0.8700
#   skyscraper         similarity=0.8698
#   flag               similarity=0.8658
#   roof               similarity=0.8589
#   corner             similarity=0.8543
#   tulip              similarity=0.8522
#   double             similarity=0.8511
#
# Most similar to 'train':
#   streetcar          similarity=0.9517
#   car                similarity=0.9109
#   bus                similarity=0.9095
#   vehicle            similarity=0.8912
#   van                similarity=0.8767
#   tracks             similarity=0.8718
#   truck              similarity=0.8685
#   track              similarity=0.8638
#
# Most similar to 'two':
#   four               similarity=0.9428
#   three              similarity=0.9405
#   shadow             similarity=0.9044
#   one                similarity=0.9038
#   there              similarity=0.9004
#   black              similarity=0.8999
#   several            similarity=0.8977
#   visible            similarity=0.8936
#
# Most similar to 'grass':
#   worm               similarity=0.9561
#   forest             similarity=0.9525
#   mushroom           similarity=0.9443
#   shrew              similarity=0.9382
#   oak_tree           similarity=0.9376
#   snail              similarity=0.9370
#   skunk              similarity=0.9324
#   maple_tree         similarity=0.9295
#
# Most similar to 'an':
#   his                similarity=0.7522
#   are                similarity=0.7456
#   can                similarity=0.7323
#   and                similarity=0.7323
#   to                 similarity=0.7066
#   is                 similarity=0.6893
#   on                 similarity=0.6588
#   in                 similarity=0.6512
#
# Most similar to 'side':
#   bottom             similarity=0.8704
#   corner             similarity=0.8686
#   front              similarity=0.8617
#   back               similarity=0.8612
#   middle             similarity=0.8502
#   rear               similarity=0.8413
#   right              similarity=0.8278
#   row                similarity=0.8197
#
# Most similar to 'large':
#   big                similarity=0.9500
#   small              similarity=0.9478
#   section            similarity=0.9289
#   sunflower          similarity=0.9122
#   photo              similarity=0.9030
#   visible            similarity=0.8993
#   one                similarity=0.8981
#   four               similarity=0.8954
#
# Most similar to 'small':
#   large              similarity=0.9478
#   big                similarity=0.9394
#   section            similarity=0.9154
#   part               similarity=0.9037
#   edge               similarity=0.9036
#   one                similarity=0.9016
#   there              similarity=0.8889
#   color              similarity=0.8872
#
# Most similar to 'street':
#   traffic            similarity=0.9132
#   stop               similarity=0.9060
#   road               similarity=0.9057
#   skyscraper         similarity=0.8949
#   sign               similarity=0.8854
#   signs              similarity=0.8843
#   streetcar          similarity=0.8825
#   city               similarity=0.8804
#
# Most similar to 'front':
#   rear               similarity=0.9629
#   back               similarity=0.9186
#   side               similarity=0.8617
#   bottom             similarity=0.8032
#   pickup_truck       similarity=0.7975
#   passenger          similarity=0.7972
#   right              similarity=0.7927
#   four               similarity=0.7919
#
# Most similar to 'ground':
#   beetle             similarity=0.9453
#   spider             similarity=0.9383
#   plain              similarity=0.9316
#   worm               similarity=0.9256
#   skunk              similarity=0.9195
#   snail              similarity=0.9146
#   mushroom           similarity=0.9140
#   cockroach          similarity=0.9139
#
# Most similar to 'top':
#   cover              similarity=0.8820
#   edge               similarity=0.8817
#   open               similarity=0.8785
#   bottom             similarity=0.8779
#   round              similarity=0.8779
#   small              similarity=0.8777
#   orchid             similarity=0.8746
#   corner             similarity=0.8732
#
# Most similar to 'plate':
#   sweet_pepper       similarity=0.9398
#   cake               similarity=0.9199
#   lobster            similarity=0.9188
#   sandwich           similarity=0.9183
#   napkin             similarity=0.9109
#   dish               similarity=0.9102
#   tray               similarity=0.9097
#   bread              similarity=0.9077
#
# Most similar to 'car':
#   vehicle            similarity=0.9670
#   van                similarity=0.9538
#   truck              similarity=0.9382
#   streetcar          similarity=0.9379
#   bus                similarity=0.9315
#   train              similarity=0.9109
#   motorcycle         similarity=0.9052
#   pickup_truck       similarity=0.8947
#
# Most similar to 'part':
#   edge               similarity=0.9485
#   section            similarity=0.9255
#   shadow             similarity=0.9193
#   there              similarity=0.9139
#   small              similarity=0.9037
#   four               similarity=0.9020
#   reflection         similarity=0.8998
#   white              similarity=0.8975
#
# Most similar to 'orange':
#   yellow             similarity=0.9520
#   purple             similarity=0.9465
#   red                similarity=0.9371
#   pink               similarity=0.9320
#   green              similarity=0.9188
#   blue               similarity=0.9051
#   pair               similarity=0.9027
#   colorful           similarity=0.8940
#
# Most similar to 'head':
#   chimpanzee         similarity=0.9392
#   face               similarity=0.9310
#   feet               similarity=0.9255
#   dinosaur           similarity=0.9100
#   snake              similarity=0.9011
#   lizard             similarity=0.8996
#   lion               similarity=0.8929
#   foot               similarity=0.8867
#
# Most similar to 'clouds':
#   sky                similarity=0.8917
#   cloud              similarity=0.8850
#   whale              similarity=0.8628
#   cloudy             similarity=0.8524
#   plain              similarity=0.8484
#   mountains          similarity=0.8454
#   sea                similarity=0.8332
#   shark              similarity=0.8242
#
# Most similar to 'wooden':
#   wood               similarity=0.9503
#   metal              similarity=0.8813
#   made               similarity=0.8577
#   beige              similarity=0.8320
#   edge               similarity=0.8288
#   brown              similarity=0.8211
#   set                similarity=0.8169
#   square             similarity=0.8115
#
# Most similar to 'standing':
#   walking            similarity=0.9600
#   looking            similarity=0.9042
#   laying             similarity=0.8727
#   sitting            similarity=0.8554
#   watching           similarity=0.8079
#   eating             similarity=0.7878
#   young              similarity=0.7744
#   riding             similarity=0.7729
#
# Most similar to 'bus':
#   streetcar          similarity=0.9497
#   vehicle            similarity=0.9349
#   truck              similarity=0.9324
#   car                similarity=0.9315
#   van                similarity=0.9233
#   train              similarity=0.9095
#   pickup_truck       similarity=0.8832
#   motorcycle         similarity=0.8731
#
# Most similar to 'pole':
#   poles              similarity=0.9238
#   post               similarity=0.9178
#   fence              similarity=0.8645
#   railing            similarity=0.8621
#   road               similarity=0.8591
#   sign               similarity=0.8569
#   street             similarity=0.8551
#   roof               similarity=0.8550
#
# Most similar to 'sitting':
#   laying             similarity=0.9098
#   looking            similarity=0.8764
#   standing           similarity=0.8554
#   walking            similarity=0.8279
#   watching           similarity=0.8241
#   holding            similarity=0.7980
#   stand              similarity=0.7865
#   being              similarity=0.7826
#
# Most similar to 'metal':
#   wooden             similarity=0.8813
#   wire               similarity=0.8695
#   wood               similarity=0.8567
#   silver             similarity=0.8473
#   square             similarity=0.8403
#   gold               similarity=0.8349
#   light              similarity=0.8314
#   round              similarity=0.8199
#
# Most similar to 'behind':
#   near               similarity=0.9566
#   beside             similarity=0.9379
#   several            similarity=0.9012
#   next               similarity=0.8966
#   between            similarity=0.8955
#   three              similarity=0.8829
#   outside            similarity=0.8821
#   many               similarity=0.8682
#
# Most similar to 'holding':
#   young              similarity=0.8645
#   carrying           similarity=0.8389
#   smiling            similarity=0.8277
#   little             similarity=0.8132
#   playing            similarity=0.8005
#   sitting            similarity=0.7980
#   being              similarity=0.7964
#   watching           similarity=0.7962
#
# Most similar to 'color':
#   colored            similarity=0.9148
#   design             similarity=0.8882
#   small              similarity=0.8872
#   orchid             similarity=0.8758
#   big                similarity=0.8729
#   large              similarity=0.8717
#   stripes            similarity=0.8649
#   top                similarity=0.8647
#
# Most similar to 'trees':
#   pine_tree          similarity=0.9665
#   willow_tree        similarity=0.9564
#   oak_tree           similarity=0.9548
#   palm_tree          similarity=0.9523
#   bushes             similarity=0.9491
#   forest             similarity=0.9452
#   maple_tree         similarity=0.9303
#   tree               similarity=0.9217
#
# Most similar to 'silver':
#   black              similarity=0.8751
#   red                similarity=0.8682
#   gold               similarity=0.8651
#   white              similarity=0.8498
#   metal              similarity=0.8473
#   round              similarity=0.8427
#   set                similarity=0.8404
#   edge               similarity=0.8384
#
# Most similar to 'snow':
#   skis               similarity=0.8848
#   mountain           similarity=0.8805
#   ski                similarity=0.8780
#   skier              similarity=0.8758
#   hill               similarity=0.8595
#   poles              similarity=0.8505
#   ground             similarity=0.8285
#   flatfish           similarity=0.8190
#
# Most similar to 'gray':
#   grey               similarity=0.9766
#   tan                similarity=0.9166
#   beige              similarity=0.9044
#   dark               similarity=0.8930
#   blue               similarity=0.8901
#   part               similarity=0.8868
#   shadow             similarity=0.8856
#   pair               similarity=0.8807
#
# Most similar to 'people':
#   men                similarity=0.9396
#   guy                similarity=0.8772
#   child              similarity=0.8480
#   lady               similarity=0.8438
#   person             similarity=0.8336
#   boy                similarity=0.8333
#   man                similarity=0.8235
#   up                 similarity=0.8180
#
# Most similar to 'dog':
#   bear               similarity=0.9359
#   cat                similarity=0.9177
#   animal             similarity=0.9133
#   cow                similarity=0.8937
#   wolf               similarity=0.8922
#   fox                similarity=0.8888
#   horse              similarity=0.8862
#   camel              similarity=0.8759
#
# Most similar to 'hand':
#   arm                similarity=0.9464
#   foot               similarity=0.8868
#   wrist              similarity=0.8719
#   hands              similarity=0.8602
#   head               similarity=0.8373
#   chimpanzee         similarity=0.8317
#   face               similarity=0.8288
#   feet               similarity=0.8209
#
# Most similar to 'road':
#   pavement           similarity=0.9145
#   streetcar          similarity=0.9121
#   street             similarity=0.9057
#   sidewalk           similarity=0.9031
#   lawn_mower         similarity=0.9018
#   tracks             similarity=0.8849
#   tractor            similarity=0.8845
#   sign               similarity=0.8798
#
# Most similar to 'tennis':
#   ball               similarity=0.8770
#   player             similarity=0.8395
#   baseball           similarity=0.8349
#   racket             similarity=0.8224
#   court              similarity=0.8153
#   frisbee            similarity=0.8096
#   game               similarity=0.7683
#   shoe               similarity=0.7418
#
# Most similar to 'hair':
#   shirt              similarity=0.8985
#   chimpanzee         similarity=0.8825
#   wardrobe           similarity=0.8671
#   coat               similarity=0.8640
#   sweater            similarity=0.8531
#   tie                similarity=0.8490
#   neck               similarity=0.8420
#   dress              similarity=0.8346
#
# Most similar to 'grey':
#   gray               similarity=0.9766
#   tan                similarity=0.9202
#   beige              similarity=0.9048
#   dark               similarity=0.8983
#   there              similarity=0.8883
#   pair               similarity=0.8871
#   shadow             similarity=0.8846
#   part               similarity=0.8811
#
# Most similar to 'dark':
#   long               similarity=0.9142
#   grey               similarity=0.8983
#   gray               similarity=0.8930
#   pair               similarity=0.8834
#   short              similarity=0.8810
#   tan                similarity=0.8798
#   very               similarity=0.8797
#   beaver             similarity=0.8760
#
# Most similar to 'glass':
#   empty              similarity=0.9092
#   clear              similarity=0.8586
#   bottle             similarity=0.8367
#   square             similarity=0.8335
#   wine               similarity=0.8316
#   round              similarity=0.8276
#   full               similarity=0.8201
#   display            similarity=0.8118
#
# Most similar to 'at':
#   on                 similarity=0.7003
#   that               similarity=0.6536
#   by                 similarity=0.6274
#   his                similarity=0.5811
#   in                 similarity=0.5665
#   an                 similarity=0.5641
#   are                similarity=0.5624
#   can                similarity=0.5615
#
# Most similar to 'plane':
#   airplane           similarity=0.9798
#   jet                similarity=0.9546
#   rocket             similarity=0.9216
#   wing               similarity=0.8843
#   engine             similarity=0.8684
#   bee                similarity=0.8171
#   train              similarity=0.8064
#   bus                similarity=0.8027
#
# Most similar to 'back':
#   front              similarity=0.9186
#   rear               similarity=0.8926
#   one                similarity=0.8811
#   side               similarity=0.8612
#   middle             similarity=0.8593
#   bottom             similarity=0.8585
#   four               similarity=0.8538
#   lion               similarity=0.8532
#
# Most similar to 'floor':
#   wall               similarity=0.9242
#   room               similarity=0.8985
#   ceiling            similarity=0.8855
#   cabinet            similarity=0.8741
#   counter            similarity=0.8652
#   shelf              similarity=0.8636
#   cockroach          similarity=0.8627
#   bed                similarity=0.8588
#
# Most similar to 'cat':
#   dog                similarity=0.9177
#   bear               similarity=0.9163
#   animal             similarity=0.8742
#   cow                similarity=0.8439
#   fox                similarity=0.8303
#   camel              similarity=0.8243
#   wolf               similarity=0.8217
#   bird               similarity=0.8178
#
# Most similar to 'background':
#   distance           similarity=0.9462
#   ground             similarity=0.9061
#   photo              similarity=0.9014
#   sunflower          similarity=0.8891
#   plain              similarity=0.8878
#   boat               similarity=0.8815
#   visible            similarity=0.8802
#   snake              similarity=0.8783
#
# Most similar to 'fence':
#   railing            similarity=0.9325
#   bench              similarity=0.9026
#   post               similarity=0.8716
#   rail               similarity=0.8656
#   pole               similarity=0.8645
#   chain              similarity=0.8634
#   worm               similarity=0.8464
#   park               similarity=0.8442
#
# Most similar to 'clock':
#   tower              similarity=0.8383
#   castle             similarity=0.8375
#   skyscraper         similarity=0.8331
#   light              similarity=0.8238
#   building           similarity=0.8057
#   lamp               similarity=0.8013
#   sign               similarity=0.7873
#   house              similarity=0.7859
#
# Most similar to 'door':
#   window             similarity=0.9008
#   handle             similarity=0.8698
#   frame              similarity=0.8656
#   cabinet            similarity=0.8651
#   ceiling            similarity=0.8610
#   wall               similarity=0.8570
#   room               similarity=0.8505
#   double             similarity=0.8471
#
# Most similar to 'giraffe':
#   camel              similarity=0.9652
#   zebra              similarity=0.9590
#   cow                similarity=0.9520
#   sheep              similarity=0.9374
#   elephant           similarity=0.9351
#   giraffes           similarity=0.9187
#   cows               similarity=0.9155
#   zebras             similarity=0.9140
#
# Most similar to 'leaves':
#   caterpillar        similarity=0.9560
#   palm_tree          similarity=0.9529
#   oak_tree           similarity=0.9502
#   maple_tree         similarity=0.9446
#   forest             similarity=0.9378
#   willow_tree        similarity=0.9377
#   branches           similarity=0.9177
#   tree               similarity=0.9074
#
# Most similar to 'boy':
#   child              similarity=0.9659
#   guy                similarity=0.9615
#   girl               similarity=0.9586
#   lady               similarity=0.9439
#   woman              similarity=0.9129
#   person             similarity=0.8978
#   man                similarity=0.8893
#   men                similarity=0.8344
#
# Most similar to 'left':
#   right              similarity=0.9802
#   back               similarity=0.8390
#   one                similarity=0.8137
#   side               similarity=0.8021
#   foot               similarity=0.7975
#   end                similarity=0.7821
#   lion               similarity=0.7820
#   middle             similarity=0.7797
#
# Most similar to 'field':
#   plain              similarity=0.8848
#   grass              similarity=0.8729
#   worm               similarity=0.8620
#   ground             similarity=0.8559
#   shrew              similarity=0.8489
#   beetle             similarity=0.8488
#   skunk              similarity=0.8458
#   spider             similarity=0.8388
#
# Most similar to 'right':
#   left               similarity=0.9802
#   back               similarity=0.8528
#   side               similarity=0.8278
#   foot               similarity=0.8230
#   one                similarity=0.8075
#   lion               similarity=0.7956
#   front              similarity=0.7927
#   middle             similarity=0.7923
#
# Most similar to 'next':
#   beside             similarity=0.9595
#   near               similarity=0.9425
#   behind             similarity=0.8966
#   between            similarity=0.8769
#   under              similarity=0.8714
#   inside             similarity=0.8576
#   outside            similarity=0.8498
#   made               similarity=0.8420
#
# Most similar to 'long':
#   short              similarity=0.9423
#   dark               similarity=0.9142
#   tiger              similarity=0.8630
#   big                similarity=0.8600
#   colored            similarity=0.8599
#   poppy              similarity=0.8558
#   large              similarity=0.8556
#   beaver             similarity=0.8548
#
# Most similar to 'by':
#   this               similarity=0.7842
#   these              similarity=0.7596
#   with               similarity=0.7338
#   to                 similarity=0.7026
#   of                 similarity=0.6994
#   can                similarity=0.6978
#   at                 similarity=0.6274
#   an                 similarity=0.6145
#
# Most similar to 'bear':
#   dog                similarity=0.9359
#   animal             similarity=0.9287
#   cat                similarity=0.9163
#   cow                similarity=0.8913
#   camel              similarity=0.8819
#   horse              similarity=0.8772
#   fox                similarity=0.8725
#   elephant           similarity=0.8671
#
# Most similar to 'chair':
#   couch              similarity=0.9160
#   bed                similarity=0.9018
#   shelf              similarity=0.8984
#   desk               similarity=0.8969
#   table              similarity=0.8862
#   bag                similarity=0.8804
#   room               similarity=0.8795
#   book               similarity=0.8784
#
# Most similar to 'elephant':
#   camel              similarity=0.9508
#   cow                similarity=0.9414
#   giraffe            similarity=0.9351
#   elephants          similarity=0.9334
#   horse              similarity=0.9322
#   zebra              similarity=0.9238
#   sheep              similarity=0.9219
#   cattle             similarity=0.9175
#
# Most similar to 'tall':
#   large              similarity=0.8907
#   several            similarity=0.8651
#   poppy              similarity=0.8565
#   sunflower          similarity=0.8473
#   big                similarity=0.8419
#   many               similarity=0.8419
#   background         similarity=0.8415
#   worm               similarity=0.8413
#
# Most similar to 'pink':
#   purple             similarity=0.9579
#   orange             similarity=0.9320
#   tan                similarity=0.8979
#   orchid             similarity=0.8885
#   red                similarity=0.8836
#   blue               similarity=0.8833
#   beige              similarity=0.8822
#   colorful           similarity=0.8807
#
# Most similar to 'man's':
#   woman's            similarity=0.9805
#   person's           similarity=0.9666
#   woman              similarity=0.7502
#   pair               similarity=0.7280
#   person             similarity=0.7277
#   man                similarity=0.7258
#   worn               similarity=0.7242
#   left               similarity=0.7067
#
# Most similar to 'girl':
#   boy                similarity=0.9586
#   child              similarity=0.9564
#   lady               similarity=0.9555
#   guy                similarity=0.9507
#   woman              similarity=0.9345
#   man                similarity=0.8865
#   person             similarity=0.8836
#   men                similarity=0.8261
#
# Most similar to 'horse':
#   camel              similarity=0.9532
#   cow                similarity=0.9463
#   horses             similarity=0.9374
#   elephant           similarity=0.9322
#   sheep              similarity=0.9317
#   cattle             similarity=0.9266
#   animal             similarity=0.8966
#   cows               similarity=0.8947
#
# Most similar to 'pizza':
#   bread              similarity=0.9583
#   sandwich           similarity=0.9525
#   sweet_pepper       similarity=0.9518
#   cheese             similarity=0.9224
#   sauce              similarity=0.9144
#   slice              similarity=0.9139
#   lobster            similarity=0.9094
#   cake               similarity=0.9058
#
# Most similar to 'for':
#   that               similarity=0.8090
#   from               similarity=0.7605
#   it                 similarity=0.7243
#   her                similarity=0.6670
#   with               similarity=0.6549
#   and                similarity=0.6387
#   this               similarity=0.6274
#   has                similarity=0.6149
#
# Most similar to 'baseball':
#   ball               similarity=0.8961
#   player             similarity=0.8589
#   tennis             similarity=0.8349
#   bat                similarity=0.8248
#   game               similarity=0.7902
#   frisbee            similarity=0.7518
#   cap                similarity=0.7452
#   glove              similarity=0.7448
#
# Most similar to 'zebra':
#   camel              similarity=0.9661
#   giraffe            similarity=0.9590
#   cow                similarity=0.9498
#   sheep              similarity=0.9330
#   zebras             similarity=0.9246
#   elephant           similarity=0.9238
#   cows               similarity=0.9220
#   elephants          similarity=0.9030
#
# Most similar to 'pants':
#   wardrobe           similarity=0.9490
#   jacket             similarity=0.9439
#   hat                similarity=0.9427
#   coat               similarity=0.9368
#   shorts             similarity=0.9323
#   backpack           similarity=0.9022
#   shoes              similarity=0.9010
#   jeans              similarity=0.8956
#
# Most similar to 'hat':
#   wardrobe           similarity=0.9548
#   pants              similarity=0.9427
#   shorts             similarity=0.9425
#   jacket             similarity=0.9329
#   sweater            similarity=0.9232
#   coat               similarity=0.9222
#   cap                similarity=0.9197
#   shoes              similarity=0.9151
#
# Most similar to 'boat':
#   sea                similarity=0.9158
#   trout              similarity=0.9137
#   whale              similarity=0.9119
#   distance           similarity=0.8948
#   otter              similarity=0.8822
#   background         similarity=0.8815
#   water              similarity=0.8803
#   crab               similarity=0.8774
#
# Most similar to 'truck':
#   vehicle            similarity=0.9524
#   van                similarity=0.9480
#   car                similarity=0.9382
#   bus                similarity=0.9324
#   pickup_truck       similarity=0.9032
#   streetcar          similarity=0.9026
#   motorcycle         similarity=0.8897
#   tractor            similarity=0.8895
#
# Most similar to 'walking':
#   standing           similarity=0.9600
#   looking            similarity=0.9073
#   riding             similarity=0.8541
#   laying             similarity=0.8455
#   sitting            similarity=0.8279
#   watching           similarity=0.8095
#   young              similarity=0.7975
#   carrying           similarity=0.7718
#
# Most similar to 'jacket':
#   coat               similarity=0.9608
#   wardrobe           similarity=0.9585
#   pants              similarity=0.9439
#   hat                similarity=0.9329
#   backpack           similarity=0.9230
#   sweater            similarity=0.9152
#   suit               similarity=0.8957
#   shorts             similarity=0.8950
#
# Most similar to 'bench':
#   fence              similarity=0.9026
#   railing            similarity=0.9001
#   park               similarity=0.8741
#   rail               similarity=0.8693
#   cockroach          similarity=0.8593
#   chair              similarity=0.8488
#   sidewalk           similarity=0.8450
#   platform           similarity=0.8424
#
# Most similar to 'sidewalk':
#   pavement           similarity=0.9427
#   road               similarity=0.9031
#   railing            similarity=0.8791
#   building           similarity=0.8786
#   street             similarity=0.8769
#   platform           similarity=0.8682
#   roof               similarity=0.8658
#   sign               similarity=0.8650
#
# Most similar to 'it':
#   that               similarity=0.8119
#   in                 similarity=0.7689
#   from               similarity=0.7406
#   for                similarity=0.7243
#   of                 similarity=0.6798
#   this               similarity=0.6705
#   with               similarity=0.6141
#   is                 similarity=0.6094
#
# Most similar to 'hanging':
#   attached           similarity=0.7783
#   visible            similarity=0.7366
#   white              similarity=0.6989
#   inside             similarity=0.6989
#   picture            similarity=0.6988
#   gold               similarity=0.6968
#   set                similarity=0.6946
#   up                 similarity=0.6914
#
# Most similar to 'toilet':
#   sink               similarity=0.8905
#   lid                similarity=0.8768
#   bathroom           similarity=0.8635
#   cabinet            similarity=0.8070
#   kitchen            similarity=0.8056
#   tank               similarity=0.7993
#   seat               similarity=0.7919
#   counter            similarity=0.7918
#
# Most similar to 'up':
#   out                similarity=0.9051
#   down               similarity=0.8938
#   off                similarity=0.8500
#   set                similarity=0.8248
#   over               similarity=0.8195
#   people             similarity=0.8180
#   inside             similarity=0.8129
#   camera             similarity=0.8116
#
# Most similar to 'bird':
#   cow                similarity=0.8668
#   animal             similarity=0.8619
#   camel              similarity=0.8599
#   zebra              similarity=0.8363
#   horse              similarity=0.8321
#   dog                similarity=0.8319
#   wolf               similarity=0.8281
#   otter              similarity=0.8248
#
# Most similar to 'tail':
#   dinosaur           similarity=0.8958
#   snake              similarity=0.8925
#   rabbit             similarity=0.8812
#   lizard             similarity=0.8774
#   raccoon            similarity=0.8702
#   lion               similarity=0.8677
#   tiger              similarity=0.8652
#   leopard            similarity=0.8648
#
# Most similar to 'bed':
#   couch              similarity=0.9417
#   chair              similarity=0.9018
#   room               similarity=0.8932
#   pillow             similarity=0.8929
#   wall               similarity=0.8853
#   shelf              similarity=0.8822
#   curtain            similarity=0.8765
#   blanket            similarity=0.8633
#
# Most similar to 'parked':
#   pickup_truck       similarity=0.8661
#   tire               similarity=0.8106
#   road               similarity=0.8000
#   lawn_mower         similarity=0.7588
#   streetcar          similarity=0.7423
#   windshield         similarity=0.7350
#   wheel              similarity=0.7350
#   pavement           similarity=0.7346
#
# Most similar to 'down':
#   up                 similarity=0.8938
#   child              similarity=0.8120
#   guy                similarity=0.8117
#   out                similarity=0.8107
#   people             similarity=0.8062
#   dog                similarity=0.8057
#   lady               similarity=0.7898
#   off                similarity=0.7861
#
# Most similar to 'near':
#   beside             similarity=0.9717
#   behind             similarity=0.9566
#   next               similarity=0.9425
#   between            similarity=0.9226
#   outside            similarity=0.8973
#   several            similarity=0.8928
#   along              similarity=0.8744
#   under              similarity=0.8714
#
# Most similar to 'wood':
#   wooden             similarity=0.9503
#   room               similarity=0.8618
#   metal              similarity=0.8567
#   square             similarity=0.8555
#   kitchen            similarity=0.8395
#   stone              similarity=0.8323
#   wall               similarity=0.8298
#   surface            similarity=0.8246
#
# Most similar to 'board':
#   trout              similarity=0.9028
#   surface            similarity=0.8739
#   boat               similarity=0.8613
#   ray                similarity=0.8602
#   aquarium_fish      similarity=0.8572
#   surfboard          similarity=0.8562
#   water              similarity=0.8556
#   flatfish           similarity=0.8495
#
# Most similar to 'from':
#   for                similarity=0.7605
#   it                 similarity=0.7406
#   on                 similarity=0.7155
#   of                 similarity=0.7004
#   is                 similarity=0.6837
#   has                similarity=0.6827
#   her                similarity=0.6675
#   in                 similarity=0.6553
#
# Most similar to 'colored':
#   color              similarity=0.9148
#   orchid             similarity=0.8883
#   design             similarity=0.8795
#   striped            similarity=0.8754
#   dark               similarity=0.8633
#   long               similarity=0.8599
#   grey               similarity=0.8576
#   tan                similarity=0.8552
#
# Most similar to 'ear':
#   eye                similarity=0.9406
#   leg                similarity=0.9031
#   lion               similarity=0.8804
#   nose               similarity=0.8706
#   dinosaur           similarity=0.8697
#   rabbit             similarity=0.8651
#   ears               similarity=0.8637
#   mouth              similarity=0.8622
#
# Most similar to 'windows':
#   skyscraper         similarity=0.9138
#   castle             similarity=0.8863
#   window             similarity=0.8662
#   streetcar          similarity=0.8499
#   lights             similarity=0.8402
#   buildings          similarity=0.8387
#   building           similarity=0.8383
#   windshield         similarity=0.8299
#
# Most similar to 'clear':
#   empty              similarity=0.8777
#   full               similarity=0.8612
#   glass              similarity=0.8586
#   top                similarity=0.8265
#   reflection         similarity=0.8235
#   aquarium_fish      similarity=0.8199
#   small              similarity=0.8184
#   large              similarity=0.8168
#
# Most similar to 'face':
#   chimpanzee         similarity=0.9414
#   head               similarity=0.9310
#   feet               similarity=0.8986
#   hands              similarity=0.8830
#   lion               similarity=0.8771
#   neck               similarity=0.8609
#   middle             similarity=0.8515
#   dinosaur           similarity=0.8507
#
# Most similar to 'motorcycle':
#   bike               similarity=0.9570
#   bicycle            similarity=0.9270
#   vehicle            similarity=0.9234
#   van                similarity=0.9143
#   car                similarity=0.9052
#   truck              similarity=0.8897
#   bus                similarity=0.8731
#   streetcar          similarity=0.8464
#
# Most similar to 'under':
#   edge               similarity=0.9069
#   inside             similarity=0.8987
#   part               similarity=0.8967
#   white              similarity=0.8920
#   three              similarity=0.8869
#   over               similarity=0.8724
#   near               similarity=0.8714
#   next               similarity=0.8714
#
# Most similar to 'umbrella':
#   blanket            similarity=0.8750
#   bag                similarity=0.8709
#   backpack           similarity=0.8674
#   wardrobe           similarity=0.8659
#   suitcase           similarity=0.8659
#   coat               similarity=0.8556
#   flag               similarity=0.8433
#   boat               similarity=0.8401
#
# Most similar to 'leg':
#   foot               similarity=0.9194
#   ear                similarity=0.9031
#   legs               similarity=0.8921
#   eye                similarity=0.8833
#   feet               similarity=0.8705
#   dinosaur           similarity=0.8632
#   head               similarity=0.8630
#   lizard             similarity=0.8599
#
# Most similar to 'player':
#   game               similarity=0.8832
#   ball               similarity=0.8675
#   baseball           similarity=0.8589
#   bat                similarity=0.8428
#   tennis             similarity=0.8395
#   racket             similarity=0.8130
#   glove              similarity=0.7955
#   boy                similarity=0.7822
#
# Most similar to 'line':
#   lines              similarity=0.9552
#   sunflower          similarity=0.9060
#   flag               similarity=0.8796
#   poppy              similarity=0.8777
#   letters            similarity=0.8761
#   butterfly          similarity=0.8758
#   writing            similarity=0.8684
#   lawn_mower         similarity=0.8625
#
# Most similar to 'over':
#   off                similarity=0.9330
#   above              similarity=0.9189
#   reflection         similarity=0.8788
#   under              similarity=0.8724
#   around             similarity=0.8609
#   picture            similarity=0.8581
#   against            similarity=0.8573
#   white              similarity=0.8486
#
# Most similar to 'helmet':
#   cap                similarity=0.9074
#   hat                similarity=0.9006
#   wardrobe           similarity=0.8936
#   glove              similarity=0.8931
#   backpack           similarity=0.8908
#   pants              similarity=0.8898
#   jacket             similarity=0.8865
#   jeans              similarity=0.8643
#
# Most similar to 'picture':
#   off                similarity=0.8898
#   set                similarity=0.8700
#   corner             similarity=0.8697
#   over               similarity=0.8581
#   photo              similarity=0.8568
#   open               similarity=0.8543
#   reflection         similarity=0.8436
#   light              similarity=0.8426
#
# Most similar to 'food':
#   sweet_pepper       similarity=0.9318
#   sandwich           similarity=0.9316
#   cake               similarity=0.9213
#   bread              similarity=0.9197
#   lobster            similarity=0.9076
#   pizza              similarity=0.9021
#   cheese             similarity=0.8915
#   pear               similarity=0.8852
#
# Most similar to 'eye':
#   ear                similarity=0.9406
#   nose               similarity=0.8848
#   leg                similarity=0.8833
#   head               similarity=0.8783
#   chimpanzee         similarity=0.8738
#   lion               similarity=0.8705
#   mouth              similarity=0.8680
#   dinosaur           similarity=0.8670
#
# Most similar to 'bag':
#   suitcase           similarity=0.8901
#   basket             similarity=0.8866
#   chair              similarity=0.8804
#   cup                similarity=0.8767
#   container          similarity=0.8722
#   umbrella           similarity=0.8709
#   blanket            similarity=0.8708
#   box                similarity=0.8673
#
# ...
#
# Most similar to 'leopard':
#   tiger              similarity=0.9733
#   wolf               similarity=0.9670
#   lion               similarity=0.9655
#   rabbit             similarity=0.9592
#   lizard             similarity=0.9564
#   crocodile          similarity=0.9551
#   dinosaur           similarity=0.9538
#   fox                similarity=0.9530
#
# Most similar to 'lion':
#   dinosaur           similarity=0.9739
#   lizard             similarity=0.9678
#   tiger              similarity=0.9659
#   leopard            similarity=0.9655
#   crocodile          similarity=0.9607
#   wolf               similarity=0.9579
#   rabbit             similarity=0.9547
#   raccoon            similarity=0.9546
#
# Most similar to 'lizard':
#   dinosaur           similarity=0.9867
#   snake              similarity=0.9845
#   kangaroo           similarity=0.9819
#   crocodile          similarity=0.9790
#   raccoon            similarity=0.9741
#   lion               similarity=0.9678
#   hamster            similarity=0.9652
#   rabbit             similarity=0.9596
#
# Most similar to 'lobster':
#   sweet_pepper       similarity=0.9497
#   cake               similarity=0.9462
#   sandwich           similarity=0.9317
#   dish               similarity=0.9229
#   bread              similarity=0.9209
#   plate              similarity=0.9188
#   pizza              similarity=0.9094
#   food               similarity=0.9076
#
# Most similar to 'maple_tree':
#   oak_tree           similarity=0.9829
#   palm_tree          similarity=0.9808
#   forest             similarity=0.9772
#   willow_tree        similarity=0.9741
#   bush               similarity=0.9644
#   pine_tree          similarity=0.9615
#   tree               similarity=0.9603
#   caterpillar        similarity=0.9593
#
# Most similar to 'mushroom':
#   worm               similarity=0.9827
#   snail              similarity=0.9823
#   skunk              similarity=0.9495
#   dirt               similarity=0.9479
#   poppy              similarity=0.9478
#   forest             similarity=0.9469
#   grass              similarity=0.9443
#   beetle             similarity=0.9424
#
# Most similar to 'oak_tree':
#   palm_tree          similarity=0.9898
#   forest             similarity=0.9874
#   willow_tree        similarity=0.9865
#   maple_tree         similarity=0.9829
#   pine_tree          similarity=0.9782
#   branches           similarity=0.9610
#   tree               similarity=0.9581
#   trees              similarity=0.9548
#
# Most similar to 'orchid':
#   rose               similarity=0.9763
#   tulip              similarity=0.9718
#   design             similarity=0.9366
#   sunflower          similarity=0.9084
#   purple             similarity=0.9071
#   poppy              similarity=0.9004
#   pink               similarity=0.8885
#   colored            similarity=0.8883
#
# Most similar to 'otter':
#   shark              similarity=0.9579
#   crab               similarity=0.9501
#   turtle             similarity=0.9373
#   ray                similarity=0.9363
#   beaver             similarity=0.9319
#   seal               similarity=0.9299
#   flatfish           similarity=0.9275
#   sea                similarity=0.9275
#
# Most similar to 'palm_tree':
#   oak_tree           similarity=0.9898
#   willow_tree        similarity=0.9814
#   maple_tree         similarity=0.9808
#   forest             similarity=0.9796
#   tree               similarity=0.9732
#   pine_tree          similarity=0.9710
#   branches           similarity=0.9675
#   bush               similarity=0.9566
#
# Most similar to 'pear':
#   fruit              similarity=0.9523
#   basket             similarity=0.9275
#   banana             similarity=0.9242
#   container          similarity=0.9121
#   bananas            similarity=0.9119
#   box                similarity=0.9092
#   sweet_pepper       similarity=0.9085
#   napkin             similarity=0.9021
#
# Most similar to 'pickup_truck':
#   streetcar          similarity=0.9107
#   wheels             similarity=0.9080
#   tractor            similarity=0.9045
#   truck              similarity=0.9032
#   windshield         similarity=0.9023
#   vehicle            similarity=0.9003
#   tire               similarity=0.8979
#   car                similarity=0.8947
#
# Most similar to 'pine_tree':
#   willow_tree        similarity=0.9811
#   oak_tree           similarity=0.9782
#   forest             similarity=0.9729
#   palm_tree          similarity=0.9710
#   trees              similarity=0.9665
#   maple_tree         similarity=0.9615
#   squirrel           similarity=0.9468
#   tree               similarity=0.9445
#
# Most similar to 'plain':
#   pine_tree          similarity=0.9347
#   ground             similarity=0.9316
#   willow_tree        similarity=0.9291
#   skunk              similarity=0.9275
#   forest             similarity=0.9215
#   spider             similarity=0.9204
#   squirrel           similarity=0.9175
#   worm               similarity=0.9151
#
# Most similar to 'poppy':
#   sunflower          similarity=0.9687
#   worm               similarity=0.9491
#   mushroom           similarity=0.9478
#   snail              similarity=0.9398
#   tulip              similarity=0.9314
#   forest             similarity=0.9142
#   rose               similarity=0.9134
#   butterfly          similarity=0.9037
#
# Most similar to 'porcupine':
#   skunk              similarity=0.9840
#   possum             similarity=0.9821
#   shrew              similarity=0.9743
#   squirrel           similarity=0.9733
#   kangaroo           similarity=0.9540
#   raccoon            similarity=0.9483
#   spider             similarity=0.9464
#   hamster            similarity=0.9434
#
# Most similar to 'possum':
#   shrew              similarity=0.9869
#   porcupine          similarity=0.9821
#   skunk              similarity=0.9723
#   raccoon            similarity=0.9655
#   squirrel           similarity=0.9626
#   kangaroo           similarity=0.9606
#   hamster            similarity=0.9565
#   spider             similarity=0.9504
#
# Most similar to 'rabbit':
#   hamster            similarity=0.9725
#   crocodile          similarity=0.9680
#   wolf               similarity=0.9666
#   fox                similarity=0.9642
#   dinosaur           similarity=0.9632
#   raccoon            similarity=0.9615
#   lizard             similarity=0.9596
#   leopard            similarity=0.9592
#
# Most similar to 'raccoon':
#   snake              similarity=0.9766
#   crocodile          similarity=0.9743
#   lizard             similarity=0.9741
#   kangaroo           similarity=0.9707
#   dinosaur           similarity=0.9691
#   possum             similarity=0.9655
#   hamster            similarity=0.9627
#   rabbit             similarity=0.9615
#
# Most similar to 'ray':
#   flatfish           similarity=0.9468
#   otter              similarity=0.9363
#   turtle             similarity=0.9238
#   shark              similarity=0.9168
#   crab               similarity=0.9130
#   photo              similarity=0.9051
#   trout              similarity=0.9029
#   sea                similarity=0.9007
#
# Most similar to 'rocket':
#   airplane           similarity=0.9252
#   plane              similarity=0.9216
#   jet                similarity=0.9116
#   engine             similarity=0.8966
#   tractor            similarity=0.8894
#   air                similarity=0.8870
#   sky                similarity=0.8770
#   streetcar          similarity=0.8756
#
# Most similar to 'rose':
#   tulip              similarity=0.9853
#   orchid             similarity=0.9763
#   flowers            similarity=0.9166
#   sunflower          similarity=0.9153
#   poppy              similarity=0.9134
#   design             similarity=0.9064
#   flower             similarity=0.9035
#   plant              similarity=0.8964
#
# Most similar to 'sea':
#   whale              similarity=0.9911
#   shark              similarity=0.9727
#   dolphin            similarity=0.9683
#   ocean              similarity=0.9575
#   trout              similarity=0.9535
#   beach              similarity=0.9482
#   water              similarity=0.9365
#   crab               similarity=0.9298
#
# Most similar to 'seal':
#   sand               similarity=0.9708
#   crab               similarity=0.9689
#   turtle             similarity=0.9407
#   beach              similarity=0.9354
#   otter              similarity=0.9299
#   flatfish           similarity=0.9286
#   shark              similarity=0.9255
#   sea                similarity=0.9151
#
# Most similar to 'shark':
#   sea                similarity=0.9727
#   whale              similarity=0.9679
#   otter              similarity=0.9579
#   dolphin            similarity=0.9577
#   trout              similarity=0.9432
#   water              similarity=0.9406
#   crab               similarity=0.9393
#   ocean              similarity=0.9393
#
# Most similar to 'shrew':
#   possum             similarity=0.9869
#   skunk              similarity=0.9771
#   porcupine          similarity=0.9743
#   hamster            similarity=0.9593
#   raccoon            similarity=0.9564
#   beetle             similarity=0.9555
#   spider             similarity=0.9531
#   kangaroo           similarity=0.9516
#
# Most similar to 'skunk':
#   porcupine          similarity=0.9840
#   shrew              similarity=0.9771
#   possum             similarity=0.9723
#   squirrel           similarity=0.9693
#   beetle             similarity=0.9637
#   spider             similarity=0.9612
#   worm               similarity=0.9559
#   forest             similarity=0.9526
#
# Most similar to 'skyscraper':
#   castle             similarity=0.9634
#   building           similarity=0.9535
#   roof               similarity=0.9175
#   buildings          similarity=0.9146
#   windows            similarity=0.9138
#   streetcar          similarity=0.9108
#   sign               similarity=0.9094
#   city               similarity=0.9055
#
# Most similar to 'snail':
#   mushroom           similarity=0.9823
#   worm               similarity=0.9669
#   poppy              similarity=0.9398
#   grass              similarity=0.9370
#   forest             similarity=0.9344
#   skunk              similarity=0.9340
#   willow_tree        similarity=0.9299
#   maple_tree         similarity=0.9273
#
# Most similar to 'snake':
#   lizard             similarity=0.9845
#   dinosaur           similarity=0.9813
#   raccoon            similarity=0.9766
#   crocodile          similarity=0.9656
#   kangaroo           similarity=0.9651
#   lion               similarity=0.9508
#   leopard            similarity=0.9434
#   possum             similarity=0.9424
#
# Most similar to 'spider':
#   beetle             similarity=0.9644
#   skunk              similarity=0.9612
#   shrew              similarity=0.9531
#   possum             similarity=0.9504
#   porcupine          similarity=0.9464
#   kangaroo           similarity=0.9430
#   ground             similarity=0.9383
#   lizard             similarity=0.9368
#
# Most similar to 'squirrel':
#   porcupine          similarity=0.9733
#   skunk              similarity=0.9693
#   possum             similarity=0.9626
#   forest             similarity=0.9530
#   shrew              similarity=0.9493
#   willow_tree        similarity=0.9490
#   pine_tree          similarity=0.9468
#   oak_tree           similarity=0.9440
#
# Most similar to 'streetcar':
#   train              similarity=0.9517
#   bus                similarity=0.9497
#   car                similarity=0.9379
#   vehicle            similarity=0.9242
#   tractor            similarity=0.9147
#   road               similarity=0.9121
#   skyscraper         similarity=0.9108
#   pickup_truck       similarity=0.9107
#
# Most similar to 'sunflower':
#   poppy              similarity=0.9687
#   butterfly          similarity=0.9412
#   tulip              similarity=0.9213
#   rose               similarity=0.9153
#   large              similarity=0.9122
#   orchid             similarity=0.9084
#   line               similarity=0.9060
#   photo              similarity=0.9053
#
# Most similar to 'sweet_pepper':
#   bread              similarity=0.9720
#   sandwich           similarity=0.9684
#   pizza              similarity=0.9518
#   lobster            similarity=0.9497
#   plate              similarity=0.9398
#   cheese             similarity=0.9382
#   cake               similarity=0.9363
#   dish               similarity=0.9352
#
# Most similar to 'telephone':
#   television         similarity=0.9692
#   keyboard           similarity=0.9582
#   laptop             similarity=0.9564
#   monitor            similarity=0.9486
#   screen             similarity=0.9392
#   computer           similarity=0.9350
#   remote             similarity=0.9217
#   mouse              similarity=0.9215
#
# Most similar to 'television':
#   telephone          similarity=0.9692
#   monitor            similarity=0.9640
#   laptop             similarity=0.9621
#   keyboard           similarity=0.9520
#   computer           similarity=0.9477
#   desk               similarity=0.9468
#   tv                 similarity=0.9445
#   screen             similarity=0.9353
#
# Most similar to 'tiger':
#   leopard            similarity=0.9733
#   lion               similarity=0.9659
#   wolf               similarity=0.9588
#   fox                similarity=0.9470
#   rabbit             similarity=0.9459
#   dinosaur           similarity=0.9426
#   lizard             similarity=0.9377
#   crocodile          similarity=0.9326
#
# Most similar to 'tractor':
#   lawn_mower         similarity=0.9712
#   streetcar          similarity=0.9147
#   vehicle            similarity=0.9091
#   pickup_truck       similarity=0.9045
#   wheels             similarity=0.9003
#   beetle             similarity=0.8953
#   skunk              similarity=0.8952
#   truck              similarity=0.8895
#
# Most similar to 'trout':
#   water              similarity=0.9599
#   sea                similarity=0.9535
#   dolphin            similarity=0.9525
#   shark              similarity=0.9432
#   crab               similarity=0.9414
#   whale              similarity=0.9374
#   aquarium_fish      similarity=0.9354
#   beach              similarity=0.9265
#
# Most similar to 'tulip':
#   rose               similarity=0.9853
#   orchid             similarity=0.9718
#   poppy              similarity=0.9314
#   flowers            similarity=0.9241
#   sunflower          similarity=0.9213
#   design             similarity=0.9170
#   flower             similarity=0.9114
#   butterfly          similarity=0.9048
#
# Most similar to 'turtle':
#   crab               similarity=0.9787
#   sand               similarity=0.9408
#   seal               similarity=0.9407
#   otter              similarity=0.9373
#   beach              similarity=0.9329
#   flatfish           similarity=0.9254
#   trout              similarity=0.9243
#   ray                similarity=0.9238
#
# Most similar to 'wardrobe':
#   coat               similarity=0.9592
#   jacket             similarity=0.9585
#   hat                similarity=0.9548
#   sweater            similarity=0.9513
#   pants              similarity=0.9490
#   backpack           similarity=0.9450
#   shorts             similarity=0.9337
#   shoes              similarity=0.9282
#
# Most similar to 'whale':
#   sea                similarity=0.9911
#   shark              similarity=0.9679
#   dolphin            similarity=0.9615
#   ocean              similarity=0.9547
#   trout              similarity=0.9374
#   waves              similarity=0.9273
#   water              similarity=0.9204
#   beach              similarity=0.9145
#
# Most similar to 'willow_tree':
#   oak_tree           similarity=0.9865
#   palm_tree          similarity=0.9814
#   pine_tree          similarity=0.9811
#   forest             similarity=0.9807
#   maple_tree         similarity=0.9741
#   trees              similarity=0.9564
#   squirrel           similarity=0.9490
#   branches           similarity=0.9485
#
# Most similar to 'wolf':
#   fox                similarity=0.9764
#   leopard            similarity=0.9670
#   rabbit             similarity=0.9666
#   hamster            similarity=0.9626
#   tiger              similarity=0.9588
#   lion               similarity=0.9579
#   crocodile          similarity=0.9573
#   lizard             similarity=0.9548
#
# Most similar to 'worm':
#   mushroom           similarity=0.9827
#   snail              similarity=0.9669
#   forest             similarity=0.9634
#   grass              similarity=0.9561
#   skunk              similarity=0.9559
#   poppy              similarity=0.9491
#   maple_tree         similarity=0.9473
#   dirt               similarity=0.9450
